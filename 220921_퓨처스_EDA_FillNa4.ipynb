# %%
import pandas as pd
import numpy as np
import matplotlib as plt

from tqdm import tqdm_notebook

# %%
loan_result = pd.read_csv("loan_result.csv")
log_data = pd.read_csv("log_data.csv")
user_spec = pd.read_csv("user_spec.csv")

# %% [markdown]
# ## 1. 대출상품결과(loan_result)

# %%
loan_result
# Out:
#           application_id loanapply_insert_time  bank_id  product_id  \
# 0                1748340   2022-06-07 13:05:41        7         191
# 1                1748340   2022-06-07 13:05:41       25         169
# 2                1748340   2022-06-07 13:05:41        2           7
# 3                1748340   2022-06-07 13:05:41        4         268
# 4                1748340   2022-06-07 13:05:41       11         118
# ...                  ...                   ...      ...         ...
# 13527358         1428218   2022-06-03 12:01:58       62         200
# 13527359         1428218   2022-06-03 12:01:49        2           7
# 13527360         1428218   2022-06-03 12:01:48       32         257
# 13527361         1428218   2022-06-03 12:01:48       33         110
# 13527362         1428218   2022-06-03 12:01:48        5         194
#
#           loan_limit  loan_rate  is_applied
# 0         42000000.0       13.6         NaN
# 1         24000000.0       17.9         NaN
# 2         24000000.0       18.5         NaN
# 3         29000000.0       10.8         NaN
# 4          5000000.0       16.4         NaN
# ...              ...        ...         ...
# 13527358   3000000.0       14.8         NaN
# 13527359  40000000.0       11.8         NaN
# 13527360  15000000.0        7.2         NaN
# 13527361  44000000.0       13.5         NaN
# 13527362  44000000.0        9.7         NaN
#
# [13527363 rows x 7 columns]

# %%
#loan_limit, loan_rate NA 존재함
loan_result.isna().sum()
# Out:
# application_id                 0
# loanapply_insert_time          0
# bank_id                        0
# product_id                     0
# loan_limit                  7495
# loan_rate                   7495
# is_applied               3257239
# dtype: int64

# %%
# 두 변수 모두 결측인 값 7495개
loan_result[(loan_result["loan_limit"].isna()) & (loan_result["loan_rate"].isna())]
# Out:
#           application_id loanapply_insert_time  bank_id  product_id  \
# 461              1029177   2022-06-07 15:29:06       51          21
# 4318             1086409   2022-06-07 18:11:31       13         262
# 6971             1193826   2022-06-07 17:13:03        1         202
# 8459              447492   2022-06-07 17:12:08       30         232
# 9220              260060   2022-06-07 11:45:43       30          85
# ...                  ...                   ...      ...         ...
# 13521728         1222550   2022-06-03 16:51:24       13         262
# 13522701          135727   2022-06-03 10:59:08       10         149
# 13523316          687402   2022-06-03 12:12:31        1         102
# 13523827          621491   2022-06-03 17:05:01       51          21
# 13526948         1719382   2022-06-03 11:31:15       13         262
#
#           loan_limit  loan_rate  is_applied
# 461              NaN        NaN         NaN
# 4318             NaN        NaN         NaN
# 6971             NaN        NaN         NaN
# 8459             NaN        NaN         NaN
# 9220             NaN        NaN         NaN
# ...              ...        ...         ...
# 13521728         NaN        NaN         NaN
# 13522701         NaN        NaN         NaN
# 13523316         NaN        NaN         NaN
# 13523827         NaN        NaN         NaN
# 13526948         NaN        NaN         NaN
#
# [7495 rows x 7 columns]

# %%
# 그 중에 대출 신청 여부도 결측인 비율 23%
loan_result[loan_result["loan_limit"].isna()]["is_applied"].isna().mean()
# Out:
# 0.2344229486324216

# %%
#중복 데이터 존재 -> 제거해야할듯
loan_result[loan_result.duplicated()]
# Out:
#           application_id loanapply_insert_time  bank_id  product_id  \
# 1507095          2160853   2022-06-16 09:47:23       10          65
# 2292642           662921   2022-06-14 12:20:50       10          65
# 2453028           361861   2022-03-10 09:16:08       10          65
# 2656633           124917   2022-03-01 18:41:01       10          65
# 3026732           893666   2022-06-21 10:34:14       10          65
# 3081480          1008438   2022-06-21 14:50:56       22         221
# 3681411           176009   2022-03-14 15:04:55       10          65
# 5455325           424582   2022-06-13 10:56:40       10          65
# 5550899           707257   2022-06-27 09:03:12       10          65
# 6231370            43839   2022-03-22 13:10:59       10          65
# 6701773           181796   2022-05-19 10:53:54       22         100
# 6893797          1716916   2022-06-18 06:20:33       10          65
# 7119371           870746   2022-06-29 13:23:51       22         164
# 7871920           410431   2022-06-23 10:10:57       10          65
# 7910401          1403169   2022-06-21 04:32:54       10          65
# 7918996           984406   2022-06-27 15:42:45       10          65
# 8513758          1257342   2022-04-27 22:25:24       10          65
# 8940949           843119   2022-06-24 10:29:43       10          65
# 9440176          1053069   2022-06-16 12:07:58       22         164
# 9455051           553201   2022-06-16 00:44:42       10          65
# 10205466         1085129   2022-05-25 02:32:32       10          65
# 11114969         1784242   2022-06-14 12:37:27       10          65
# 11385155         1583243   2022-03-08 13:22:03       10          65
# 11845315         2134854   2022-06-17 13:19:42       10          65
# 12603837         1091462   2022-04-01 07:03:51       10          65
# 12790471         2047901   2022-04-22 01:03:58       52         187
#
#           loan_limit  loan_rate  is_applied
# 1507095   29000000.0       15.6         NaN
# 2292642   19000000.0       15.6         NaN
# 2453028   36000000.0       12.2         1.0
# 2656633   50000000.0       12.2         1.0
# 3026732   34000000.0       12.7         NaN
# 3081480    3000000.0       18.4         NaN
# 3681411   31000000.0       12.2         1.0
# 5455325   43000000.0       14.2         NaN
# 5550899   50000000.0       12.7         NaN
# 6231370   28000000.0       12.5         1.0
# 6701773    5000000.0       15.8         0.0
# 6893797   32000000.0       13.9         NaN
# 7119371   20000000.0        8.5         NaN
# 7871920   18000000.0       18.0         NaN
# 7910401   70000000.0       12.7         NaN
# 7918996   33000000.0       13.3         NaN
# 8513758   15000000.0       14.2         1.0
# 8940949   53000000.0       13.9         NaN
# 9440176   18000000.0        8.5         NaN
# 9455051   50000000.0       13.9         NaN
# 10205466  37000000.0       12.4         1.0
# 11114969  65000000.0       13.9         NaN
# 11385155  52000000.0       12.1         1.0
# 11845315  50000000.0       12.7         NaN
# 12603837  70000000.0       14.2         1.0
# 12790471   3000000.0        6.2         0.0

# %% [markdown]
# ### is_applicated : NA

# %%
loan_result["is_applied"].isna().mean()
# Out:
# 0.24078891059550928

# %%
# is_applied가 결측인 행 -> test 데이터
# 6월1일 ~ 6월30일

print(loan_result[loan_result["is_applied"].isna()]["loanapply_insert_time"].min())
print(loan_result[loan_result["is_applied"].isna()]["loanapply_insert_time"].max())
# Out:
# 2022-06-01 00:12:24
# 2022-06-30 23:55:00

# %%
# is_applied가 결측이 아닌 행 -> train 데이터
# 3월1일 ~ 5월31일

print(loan_result[-loan_result["is_applied"].isna()]["loanapply_insert_time"].min())
print(loan_result[-loan_result["is_applied"].isna()]["loanapply_insert_time"].max())
# Out:
# 2022-03-01 00:11:36
# 2022-05-31 23:54:38

# %% [markdown]
# ## 2. 유저로그데이터(log_data)

# %%
log_data
# Out:
#           user_id               event            timestamp    mp_os  \
# 0          576409      StartLoanApply  2022-03-25 11:12:09  Android
# 1          576409  ViewLoanApplyIntro  2022-03-25 11:12:09  Android
# 2           72878        EndLoanApply  2022-03-25 11:14:44  Android
# 3          645317             OpenApp  2022-03-25 11:15:09      iOS
# 4          645317       UseLoanManage  2022-03-25 11:15:11      iOS
# ...           ...                 ...                  ...      ...
# 17843988   242442      StartLoanApply  2022-05-27 16:08:21  Android
# 17843989   242442        EndLoanApply  2022-05-27 16:08:21  Android
# 17843990   593062             OpenApp  2022-05-27 16:19:10  Android
# 17843991   593062               Login  2022-05-27 16:19:15  Android
# 17843992   593062       UseLoanManage  2022-05-27 16:19:19  Android
#
#          mp_app_version     date_cd
# 0                 3.8.2  2022-03-25
# 1                 3.8.2  2022-03-25
# 2                 3.8.4  2022-03-25
# 3                 3.6.1  2022-03-25
# 4                 3.6.1  2022-03-25
# ...                 ...         ...
# 17843988         3.13.0  2022-05-27
# 17843989         3.13.0  2022-05-27
# 17843990         3.13.0  2022-05-27
# 17843991         3.13.0  2022-05-27
# 17843992         3.13.0  2022-05-27
#
# [17843993 rows x 6 columns]

# %%
log_data.isna().sum()
# Out:
# user_id                0
# event                  0
# timestamp              0
# mp_os                980
# mp_app_version    660597
# date_cd                0
# dtype: int64

# %% [markdown]
# ## 3. 유저스펙테이블(user_spec)

# %%
user_spec
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 0               1249046   118218      1985.0     1.0  2022-06-07 06:28:18
# 1                954900   553686      1968.0     1.0  2022-06-07 14:29:03
# 2                137274    59516      1997.0     1.0  2022-06-07 21:40:22
# 3               1570936   167320      1989.0     1.0  2022-06-07 09:40:27
# 4                967833    33400      2000.0     1.0  2022-06-07 08:55:07
# ...                 ...      ...         ...     ...                  ...
# 1394211         1864587   489900      2000.0     1.0  2022-03-22 14:55:32
# 1394212         1327066   151422      1955.0     1.0  2022-03-22 01:19:24
# 1394213         1319606   173524      1983.0     1.0  2022-03-22 07:34:32
# 1394214         1482466   766546      1975.0     1.0  2022-03-22 22:12:35
# 1394215          816537     3864      1977.0     0.0  2022-03-22 08:55:14
#
#          credit_score  yearly_income      income_type  company_enter_month  \
# 0               660.0    108000000.0  PRIVATEBUSINESS           20151101.0
# 1               870.0     30000000.0  PRIVATEBUSINESS           20070201.0
# 2               710.0     30000000.0       FREELANCER           20210901.0
# 3               820.0     62000000.0     EARNEDINCOME           20170101.0
# 4               630.0     36000000.0     EARNEDINCOME           20210901.0
# ...               ...            ...              ...                  ...
# 1394211         590.0     25000000.0       FREELANCER             202106.0
# 1394212         980.0     20000000.0      OTHERINCOME                  NaN
# 1394213         750.0     75000000.0     EARNEDINCOME             200908.0
# 1394214         640.0     50000000.0     EARNEDINCOME             201705.0
# 1394215           NaN     35000000.0       FREELANCER             201103.0
#
#         employment_type houseown_type  desired_amount purpose  \
# 0                    기타            자가       1000000.0      기타
# 1                   정규직        기타가족소유      30000000.0    대환대출
# 2                    기타        기타가족소유      10000000.0     생활비
# 3                   정규직            자가       2000000.0     생활비
# 4                   정규직        기타가족소유       5000000.0     생활비
# ...                 ...           ...             ...     ...
# 1394211              기타        기타가족소유       5000000.0    사업자금
# 1394212              기타            자가      50000000.0     생활비
# 1394213             정규직            자가     100000000.0    대환대출
# 1394214             정규직            자가      10000000.0    대환대출
# 1394215              기타            자가      20000000.0     생활비
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 0                               0.0                                  NaN
# 1                               0.0                                  NaN
# 2                               0.0                                  NaN
# 3                               0.0                                  NaN
# 4                               0.0                                  0.0
# ...                             ...                                  ...
# 1394211                         NaN                                  NaN
# 1394212                         NaN                                  NaN
# 1394213                         NaN                                  NaN
# 1394214                         NaN                                  NaN
# 1394215                         NaN                                  NaN
#
#          existing_loan_cnt  existing_loan_amt
# 0                      4.0        162000000.0
# 1                      1.0         27000000.0
# 2                      5.0         15000000.0
# 3                      7.0        344000000.0
# 4                      1.0         16000000.0
# ...                    ...                ...
# 1394211                NaN                NaN
# 1394212                1.0                NaN
# 1394213                8.0        200000000.0
# 1394214               10.0        117000000.0
# 1394215                NaN                NaN
#
# [1394216 rows x 17 columns]

# %%
# 결측값이 매우 많음
user_spec.isna().sum()
# Out:
# application_id                               0
# user_id                                      0
# birth_year                               12961
# gender                                   12961
# insert_time                                  0
# credit_score                            105115
# yearly_income                               90
# income_type                                 85
# company_enter_month                     171760
# employment_type                             85
# houseown_type                               85
# desired_amount                              85
# purpose                                     85
# personal_rehabilitation_yn              587461
# personal_rehabilitation_complete_yn    1203354
# existing_loan_cnt                       198556
# existing_loan_amt                       313774
# dtype: int64

# %%
# 데이터 전체 행 수 : 1,394,216
len(user_spec)
# Out:
# 1394216

# %%
# application_id(신청서) 수 : 1,394,216 ( == 데이터 전체 행 수)
len(user_spec["application_id"].unique())
# Out:
# 1394216

# %%
# user_id(이용자) 수 : 405,213
## 평균적으로 이용자 한 명당 약 3번 정도 핀다 신청을 함
len(user_spec["user_id"].unique())
# Out:
# 405213

# %% [markdown]
# #### loan_result의 "application_id"와 user_spec의 "application_id"를 기준으로 merge

# %% [markdown]
# loan_resul에는 있지만 user_spec에는 없는 경우

# %%
tmp = pd.merge(loan_result,user_spec, how='left',on='application_id')

# %%
# 이 중에서 user_id가 결측인 값 => loan_result에 있는 application_id가 user_spec에는 없었다. 113개
# user에 대한 정보를 얻을 수 없다면 제거하는게 적절하다고 봄.
tmp[tmp["user_id"].isna()]
# Out:
#           application_id loanapply_insert_time  bank_id  product_id  \
# 68010            2015764   2022-04-29 15:16:36       27         193
# 615673           1669381   2022-03-01 18:03:44       14         197
# 1694465           351899   2022-04-18 14:00:08        1          61
# 2978297          1382876   2022-03-01 18:02:54       14         197
# 3125384          2061284   2022-05-04 10:03:07        1          61
# ...                  ...                   ...      ...         ...
# 13373186          197821   2022-03-02 10:29:03       13         262
# 13386339          398321   2022-03-02 15:17:30       10         149
# 13387297         1872250   2022-03-02 11:01:23       34          57
# 13403453         2052437   2022-03-02 17:24:59       30         121
# 13417527         1610455   2022-03-02 16:29:09       13         262
#
#           loan_limit  loan_rate  is_applied  user_id  birth_year  gender  ...  \
# 68010            NaN        NaN         1.0      NaN         NaN     NaN  ...
# 615673           NaN        NaN         1.0      NaN         NaN     NaN  ...
# 1694465          NaN        NaN         1.0      NaN         NaN     NaN  ...
# 2978297          NaN        NaN         1.0      NaN         NaN     NaN  ...
# 3125384          NaN        NaN         1.0      NaN         NaN     NaN  ...
# ...              ...        ...         ...      ...         ...     ...  ...
# 13373186         NaN        NaN         1.0      NaN         NaN     NaN  ...
# 13386339         NaN        NaN         1.0      NaN         NaN     NaN  ...
# 13387297         NaN        NaN         1.0      NaN         NaN     NaN  ...
# 13403453         NaN        NaN         1.0      NaN         NaN     NaN  ...
# 13417527         NaN        NaN         1.0      NaN         NaN     NaN  ...
#
#          income_type  company_enter_month  employment_type houseown_type  \
# 68010            NaN                  NaN              NaN           NaN
# 615673           NaN                  NaN              NaN           NaN
# 1694465          NaN                  NaN              NaN           NaN
# 2978297          NaN                  NaN              NaN           NaN
# 3125384          NaN                  NaN              NaN           NaN
# ...              ...                  ...              ...           ...
# 13373186         NaN                  NaN              NaN           NaN
# 13386339         NaN                  NaN              NaN           NaN
# 13387297         NaN                  NaN              NaN           NaN
# 13403453         NaN                  NaN              NaN           NaN
# 13417527         NaN                  NaN              NaN           NaN
#
#           desired_amount purpose personal_rehabilitation_yn  \
# 68010                NaN     NaN                        NaN
# 615673               NaN     NaN                        NaN
# 1694465              NaN     NaN                        NaN
# 2978297              NaN     NaN                        NaN
# 3125384              NaN     NaN                        NaN
# ...                  ...     ...                        ...
# 13373186             NaN     NaN                        NaN
# 13386339             NaN     NaN                        NaN
# 13387297             NaN     NaN                        NaN
# 13403453             NaN     NaN                        NaN
# 13417527             NaN     NaN                        NaN
#
#           personal_rehabilitation_complete_yn existing_loan_cnt  \
# 68010                                     NaN               NaN
# 615673                                    NaN               NaN
# 1694465                                   NaN               NaN
# 2978297                                   NaN               NaN
# 3125384                                   NaN               NaN
# ...                                       ...               ...
# 13373186                                  NaN               NaN
# 13386339                                  NaN               NaN
# 13387297                                  NaN               NaN
# 13403453                                  NaN               NaN
# 13417527                                  NaN               NaN
#
#           existing_loan_amt
# 68010                   NaN
# 615673                  NaN
# 1694465                 NaN
# 2978297                 NaN
# 3125384                 NaN
# ...                     ...
# 13373186                NaN
# 13386339                NaN
# 13387297                NaN
# 13403453                NaN
# 13417527                NaN
#
# [113 rows x 23 columns]

# %%
# 113개 전부 대출 신청한 상품임
tmp[tmp["user_id"].isna()]["is_applied"].sum()
# Out:
# 113.0

# %% [markdown]
# user_spec에는 있지만 loan_resul에는 없는 경우

# %%
tt = pd.DataFrame()
tt["application_id"] = loan_result["application_id"].unique()
tt["dong"] = 1

tmp = pd.merge(user_spec,tt, how='left',on='application_id')

(tmp["dong"].isna()).sum()
# Out:
# 425463

# %% [markdown]
# ## user_spec EDA

# %%
user_spec.isna().sum()
# Out:
# application_id                               0
# user_id                                      0
# birth_year                               12961
# gender                                   12961
# insert_time                                  0
# credit_score                            105115
# yearly_income                               90
# income_type                                 85
# company_enter_month                     171760
# employment_type                             85
# houseown_type                               85
# desired_amount                              85
# purpose                                     85
# personal_rehabilitation_yn              587461
# personal_rehabilitation_complete_yn    1203354
# existing_loan_cnt                       198556
# existing_loan_amt                       313774
# dtype: int64

# %%
user_spec0 = user_spec.copy()
user_spec = user_spec0.copy()

# %% [markdown]
# #### 날짜 형식 맞춰주기

# %%
# company_enter_month
company_enter_month_d = []
for i in tqdm_notebook(user_spec["company_enter_month"].astype(str)):
    try:
        company_enter_month_d.append(pd.to_datetime(i[0:6]+"01"))
    except:
        company_enter_month_d.append(np.nan)
# Out:
# <ipython-input-24-ea4bc05fa1fd>:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(user_spec["company_enter_month"].astype(str)):
#   0%|          | 0/1394216 [00:00<?, ?it/s]

# %%
user_spec["company_enter_month"] = company_enter_month_d

# %%
# insert_time
user_spec["insert_time"] = pd.to_datetime(user_spec["insert_time"])

# %% [markdown]
# #### 개인정보 결측

# %%
#income_type, employment_type, houseown_type, desired_amount, purpose 결측 85개
#yearly_income 결측 85개
user_info_na = user_spec[(user_spec["income_type"].isna()) & (user_spec["employment_type"].isna()) & 
         (user_spec["houseown_type"].isna()) & (user_spec["desired_amount"].isna()) & 
                (user_spec["purpose"].isna()) & (user_spec["yearly_income"].isna())]
user_info_na
# Out:
#          application_id  user_id  birth_year  gender         insert_time  \
# 5353             129515   135984      1974.0     1.0 2022-06-13 18:26:44
# 8864            1468193   151012      1996.0     1.0 2022-06-16 16:34:35
# 17484           1234909   596908      1996.0     0.0 2022-06-16 16:28:10
# 17552           1068316   142003      1976.0     0.0 2022-06-16 16:28:59
# 20510           2082836   827892      1993.0     1.0 2022-06-16 16:30:46
# ...                 ...      ...         ...     ...                 ...
# 1360335          450732   387671      1965.0     1.0 2022-06-16 16:30:17
# 1363322          657920   839689      1995.0     1.0 2022-06-16 16:31:02
# 1367643          596953   264147      1984.0     1.0 2022-06-30 16:32:56
# 1378239          999720   738199      1972.0     1.0 2022-03-12 21:49:37
# 1388506         1223986   118147      1998.0     0.0 2022-06-16 16:33:02
#
#          credit_score  yearly_income income_type company_enter_month  \
# 5353            750.0            NaN         NaN                 NaT
# 8864            810.0            NaN         NaN                 NaT
# 17484           640.0            NaN         NaN                 NaT
# 17552           770.0            NaN         NaN                 NaT
# 20510           940.0            NaN         NaN                 NaT
# ...               ...            ...         ...                 ...
# 1360335         650.0            NaN         NaN                 NaT
# 1363322         770.0            NaN         NaN                 NaT
# 1367643         630.0            NaN         NaN                 NaT
# 1378239         520.0            NaN         NaN                 NaT
# 1388506         560.0            NaN         NaN                 NaT
#
#         employment_type houseown_type  desired_amount purpose  \
# 5353                NaN           NaN             NaN     NaN
# 8864                NaN           NaN             NaN     NaN
# 17484               NaN           NaN             NaN     NaN
# 17552               NaN           NaN             NaN     NaN
# 20510               NaN           NaN             NaN     NaN
# ...                 ...           ...             ...     ...
# 1360335             NaN           NaN             NaN     NaN
# 1363322             NaN           NaN             NaN     NaN
# 1367643             NaN           NaN             NaN     NaN
# 1378239             NaN           NaN             NaN     NaN
# 1388506             NaN           NaN             NaN     NaN
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 5353                            NaN                                  NaN
# 8864                            NaN                                  NaN
# 17484                           NaN                                  NaN
# 17552                           NaN                                  NaN
# 20510                           NaN                                  NaN
# ...                             ...                                  ...
# 1360335                         NaN                                  NaN
# 1363322                         NaN                                  NaN
# 1367643                         NaN                                  NaN
# 1378239                         NaN                                  NaN
# 1388506                         NaN                                  NaN
#
#          existing_loan_cnt  existing_loan_amt
# 5353                   4.0         67000000.0
# 8864                   2.0          6000000.0
# 17484                  3.0         36000000.0
# 17552                  NaN                NaN
# 20510                  3.0         61000000.0
# ...                    ...                ...
# 1360335                1.0          6000000.0
# 1363322                4.0         16000000.0
# 1367643                1.0          1000000.0
# 1378239                2.0          2000000.0
# 1388506                NaN                NaN
#
# [85 rows x 17 columns]

# %% [markdown]
# 위의 85개 경우는 전부 loan_result에 없는 application_id 이다.

# %%
app = user_info_na["application_id"]

# %%
l_list = []
for i in app:
    l_list.append(len(loan_result[loan_result["application_id"] == i]))

# %%
np.unique(l_list)
# Out:
# array([0])

# %% [markdown]
# yearly_income만 결측

# %%
# yearly_income만 결측인 값 5개
user_spec[(-user_spec["purpose"].isna()) & (user_spec["yearly_income"].isna())]
# Out:
#         application_id  user_id  birth_year  gender         insert_time  \
# 165422         1026915   861363      1995.0     1.0 2022-06-30 21:11:51
# 233316         2045613   702899      1995.0     1.0 2022-06-30 18:37:04
# 597591          391560   329226      1996.0     0.0 2022-06-30 19:27:28
# 597613          341149   670502      1981.0     1.0 2022-06-30 21:32:18
# 971960         1330905   771592      2003.0     1.0 2022-06-30 18:57:05
#
#         credit_score  yearly_income  income_type company_enter_month  \
# 165422           NaN            NaN  OTHERINCOME                 NaT
# 233316         520.0            NaN   FREELANCER          2022-06-01
# 597591         590.0            NaN  OTHERINCOME                 NaT
# 597613         930.0            NaN  OTHERINCOME                 NaT
# 971960         750.0            NaN  OTHERINCOME                 NaT
#
#        employment_type houseown_type  desired_amount purpose  \
# 165422              기타           전월세       5000000.0     생활비
# 233316              기타           전월세       5000000.0  전월세보증금
# 597591              기타           전월세      20000000.0     생활비
# 597613              기타        기타가족소유       6000000.0    사업자금
# 971960              기타            자가       3000000.0     생활비
#
#         personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 165422                         0.0                                  0.0
# 233316                         0.0                                  0.0
# 597591                         0.0                                  0.0
# 597613                         0.0                                  0.0
# 971960                         0.0                                  0.0
#
#         existing_loan_cnt  existing_loan_amt
# 165422                NaN                NaN
# 233316                1.0          1000000.0
# 597591                9.0         27000000.0
# 597613                1.0          3000000.0
# 971960                1.0          3000000.0

# %%
tmp["insert_time"].max()
# Out:
# '2022-06-30 23:58:29'

# %%
user_spec[(-user_spec["purpose"].isna()) & (-user_spec["yearly_income"].isna())]["insert_time"].max()
# Out:
# Timestamp('2022-06-30 23:58:29')

# %% [markdown]
# #### 신용점수

# %%
tmp = user_spec[user_spec["credit_score"].isna()]
tmp
# Out:
#          application_id  user_id  birth_year  gender         insert_time  \
# 25               272600   754046      1980.0     1.0 2022-06-07 19:24:28
# 39               246114   470525      1983.0     1.0 2022-06-07 22:00:53
# 48               612258    59149      1998.0     1.0 2022-06-07 07:31:21
# 64              1036265   558745      1986.0     0.0 2022-06-07 17:20:08
# 65              1930194   157472      1995.0     1.0 2022-06-07 16:34:09
# ...                 ...      ...         ...     ...                 ...
# 1394120         1281112   493197      1987.0     1.0 2022-03-22 12:06:34
# 1394127         1121565    82805      1992.0     1.0 2022-03-22 11:42:39
# 1394141         1229782   250565      1989.0     1.0 2022-03-22 21:12:37
# 1394179         1264282    10298      1999.0     1.0 2022-03-22 14:31:24
# 1394215          816537     3864      1977.0     0.0 2022-03-22 08:55:14
#
#          credit_score  yearly_income      income_type company_enter_month  \
# 25                NaN     22000000.0     EARNEDINCOME          2009-01-01
# 39                NaN     45000000.0      OTHERINCOME                 NaT
# 48                NaN            0.0  PRIVATEBUSINESS          2022-03-01
# 64                NaN     48000000.0     EARNEDINCOME          2012-10-01
# 65                NaN     40000000.0     EARNEDINCOME          2022-05-01
# ...               ...            ...              ...                 ...
# 1394120           NaN    100000000.0  PRIVATEBUSINESS          2021-10-01
# 1394127           NaN     30000000.0     EARNEDINCOME          2018-01-01
# 1394141           NaN     44000000.0     EARNEDINCOME          2018-04-01
# 1394179           NaN     10000000.0       FREELANCER          2021-06-01
# 1394215           NaN     35000000.0       FREELANCER          2011-03-01
#
#         employment_type houseown_type  desired_amount purpose  \
# 25                  정규직           전월세      22000000.0    대환대출
# 39                   기타           전월세      30000000.0    사업자금
# 48                   기타           전월세       1000000.0     생활비
# 64                  정규직            자가     280000000.0    주택구입
# 65                  정규직        기타가족소유       7000000.0     생활비
# ...                 ...           ...             ...     ...
# 1394120             정규직        기타가족소유      50000000.0    사업자금
# 1394127             정규직           전월세      10000000.0  LIVING
# 1394141             정규직           전월세      20000000.0      기타
# 1394179              기타        기타가족소유       3000000.0  전월세보증금
# 1394215              기타            자가      20000000.0     생활비
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 25                              0.0                                  NaN
# 39                              0.0                                  NaN
# 48                              0.0                                  0.0
# 64                              0.0                                  NaN
# 65                              0.0                                  0.0
# ...                             ...                                  ...
# 1394120                         NaN                                  NaN
# 1394127                         NaN                                  NaN
# 1394141                         NaN                                  NaN
# 1394179                         NaN                                  NaN
# 1394215                         NaN                                  NaN
#
#          existing_loan_cnt  existing_loan_amt
# 25                     NaN                NaN
# 39                     1.0                NaN
# 48                     NaN                NaN
# 64                     NaN                NaN
# 65                     NaN                NaN
# ...                    ...                ...
# 1394120                NaN                NaN
# 1394127                NaN                NaN
# 1394141                NaN                NaN
# 1394179                NaN                NaN
# 1394215                NaN                NaN
#
# [105115 rows x 17 columns]

# %%
tmp.value_counts("employment_type")
# Out:
# employment_type
# 정규직    63748
# 기타     32630
# 계약직     7690
# 일용직     1044
# dtype: int64

# %% [markdown]
# #### income_type, employment_type, houseown_type 비율

# %%
user_spec["income_type"].value_counts()
# Out:
# EARNEDINCOME       892579
# OTHERINCOME        172600
# PRIVATEBUSINESS    126108
# FREELANCER         103913
# EARNEDINCOME2       78806
# PRACTITIONER        20125
# Name: income_type, dtype: int64

# %%
user_spec["employment_type"].value_counts()
# Out:
# 정규직    918032
# 기타     345801
# 계약직    111445
# 일용직     18853
# Name: employment_type, dtype: int64

# %%
user_spec["houseown_type"].value_counts()
# Out:
# 전월세       642838
# 기타가족소유    465893
# 자가        283454
# 배우자         1946
# Name: houseown_type, dtype: int64

# %%
user_spec["purpose"].value_counts()
# Out:
# 생활비             866079
# 대환대출            353794
# 사업자금             62115
# 기타               30132
# 전월세보증금           27236
# 주택구입             17471
# LIVING           15432
# 투자               12532
# 자동차구입             3394
# SWITCHLOAN        3248
# BUSINESS           935
# ETC                593
# HOUSEDEPOSIT       562
# BUYHOUSE           307
# INVEST             166
# BUYCAR             135
# Name: purpose, dtype: int64

# %%
user_spec[user_spec["purpose"] == "자동차구입"]
# Out:
#          application_id  user_id  birth_year  gender         insert_time  \
# 526             2051119   274384      1995.0     0.0 2022-06-07 21:02:00
# 582              596302   320993      2001.0     1.0 2022-06-07 20:53:31
# 771             1800061   684065      1997.0     1.0 2022-05-05 00:40:01
# 778              622314    75657      1985.0     1.0 2022-05-05 22:13:23
# 882             1929925   362989      1997.0     1.0 2022-04-24 20:55:47
# ...                 ...      ...         ...     ...                 ...
# 1392967         1030211   576750      1974.0     1.0 2022-03-21 18:53:16
# 1393192           42575   834644      1990.0     0.0 2022-03-04 14:02:44
# 1393602          800366   193059      1994.0     0.0 2022-04-27 21:21:55
# 1393917         1168588   642451      1995.0     1.0 2022-06-26 17:08:52
# 1394110          733088    32260      1977.0     0.0 2022-03-22 21:32:47
#
#          credit_score  yearly_income    income_type company_enter_month  \
# 526             580.0     40000000.0   EARNEDINCOME          2021-03-01
# 582               NaN     42000000.0     FREELANCER          2021-11-01
# 771             590.0     20000000.0   PRACTITIONER          2022-03-01
# 778             870.0     25000000.0   EARNEDINCOME          2021-03-01
# 882             840.0     36000000.0  EARNEDINCOME2          2021-11-01
# ...               ...            ...            ...                 ...
# 1392967         750.0     10000000.0    OTHERINCOME                 NaT
# 1393192         540.0     25000000.0  EARNEDINCOME2          2017-10-01
# 1393602           NaN     26000000.0   EARNEDINCOME          2022-01-01
# 1393917         700.0     60000000.0   PRACTITIONER          2021-06-01
# 1394110         620.0    100000000.0    OTHERINCOME                 NaT
#
#         employment_type houseown_type  desired_amount purpose  \
# 526                 정규직           전월세      20000000.0   자동차구입
# 582                  기타        기타가족소유       4000000.0   자동차구입
# 771                 일용직        기타가족소유       3000000.0   자동차구입
# 778                 정규직        기타가족소유      10000000.0   자동차구입
# 882                 계약직           전월세      16000000.0   자동차구입
# ...                 ...           ...             ...     ...
# 1392967              기타           전월세      40000000.0   자동차구입
# 1393192             계약직        기타가족소유      25000000.0   자동차구입
# 1393602             정규직        기타가족소유      16000000.0   자동차구입
# 1393917             계약직        기타가족소유      20000000.0   자동차구입
# 1394110              기타        기타가족소유      30000000.0   자동차구입
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 526                             0.0                                  0.0
# 582                             NaN                                  NaN
# 771                             0.0                                  NaN
# 778                             0.0                                  0.0
# 882                             0.0                                  NaN
# ...                             ...                                  ...
# 1392967                         NaN                                  NaN
# 1393192                         NaN                                  NaN
# 1393602                         0.0                                  NaN
# 1393917                         0.0                                  NaN
# 1394110                         NaN                                  NaN
#
#          existing_loan_cnt  existing_loan_amt
# 526                    1.0          4000000.0
# 582                    NaN                NaN
# 771                    3.0         15000000.0
# 778                    1.0                0.0
# 882                    1.0                NaN
# ...                    ...                ...
# 1392967                NaN                NaN
# 1393192                3.0         19000000.0
# 1393602                NaN                NaN
# 1393917                NaN                NaN
# 1394110                1.0                NaN
#
# [3394 rows x 17 columns]

# %%
user_spec[user_spec["purpose"] == "BUYCAR"]
# Out:
#          application_id  user_id  birth_year  gender         insert_time  \
# 3235            1166745   526389      1974.0     0.0 2022-04-20 00:48:48
# 5738            1356707   678849      1975.0     1.0 2022-04-26 14:08:23
# 22921            742660   129688      1975.0     1.0 2022-04-04 15:48:15
# 23536           2019370   390166      1991.0     1.0 2022-03-24 07:24:23
# 23554            412813   481732      1972.0     1.0 2022-03-24 17:23:55
# ...                 ...      ...         ...     ...                 ...
# 1347169         1734729    64817      1998.0     1.0 2022-03-03 20:02:13
# 1353361         2111704   381486      1973.0     1.0 2022-05-06 17:44:55
# 1363225         1283771   297050      1996.0     1.0 2022-05-02 16:56:39
# 1371759          101254   799478      1983.0     1.0 2022-05-01 10:46:38
# 1391639          914818   114993      1997.0     0.0 2022-04-21 00:39:03
#
#          credit_score  yearly_income      income_type company_enter_month  \
# 3235            670.0     40000000.0     EARNEDINCOME          2015-04-01
# 5738            980.0     50000000.0       FREELANCER          2022-01-01
# 22921             NaN     36000000.0     EARNEDINCOME          2013-01-01
# 23536             NaN     75000000.0     EARNEDINCOME          2013-11-01
# 23554             NaN     36000000.0     EARNEDINCOME          2021-12-01
# ...               ...            ...              ...                 ...
# 1347169           NaN     36000000.0     EARNEDINCOME          2021-12-01
# 1353361         940.0     50000000.0     EARNEDINCOME          2021-08-01
# 1363225           NaN     30000000.0     EARNEDINCOME          2014-09-01
# 1371759           NaN     50000000.0     EARNEDINCOME          2018-08-01
# 1391639           NaN     75000000.0  PRIVATEBUSINESS          2022-01-01
#
#         employment_type houseown_type  desired_amount purpose  \
# 3235                정규직            자가      30000000.0  BUYCAR
# 5738                 기타            자가      20000000.0  BUYCAR
# 22921               정규직            자가      25000000.0  BUYCAR
# 23536               정규직            자가      10000000.0  BUYCAR
# 23554               정규직           전월세      10000000.0  BUYCAR
# ...                 ...           ...             ...     ...
# 1347169             계약직        기타가족소유      30000000.0  BUYCAR
# 1353361             정규직            자가      13000000.0  BUYCAR
# 1363225             정규직           전월세      20000000.0  BUYCAR
# 1371759             정규직           전월세      30000000.0  BUYCAR
# 1391639              기타           전월세      40000000.0  BUYCAR
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 3235                            NaN                                  NaN
# 5738                            NaN                                  NaN
# 22921                           NaN                                  NaN
# 23536                           NaN                                  NaN
# 23554                           NaN                                  NaN
# ...                             ...                                  ...
# 1347169                         NaN                                  NaN
# 1353361                         NaN                                  NaN
# 1363225                         NaN                                  NaN
# 1371759                         NaN                                  NaN
# 1391639                         NaN                                  NaN
#
#          existing_loan_cnt  existing_loan_amt
# 3235                   3.0         30000000.0
# 5738                   NaN                NaN
# 22921                  NaN                NaN
# 23536                  NaN                NaN
# 23554                  2.0         23000000.0
# ...                    ...                ...
# 1347169                NaN                NaN
# 1353361                1.0                NaN
# 1363225                NaN                NaN
# 1371759                NaN                NaN
# 1391639                3.0          7000000.0
#
# [135 rows x 17 columns]

# %% [markdown]
# #### existing_loan_cnt, existing_loan_amt

# %%
user_spec[user_spec["existing_loan_cnt"].isna()]
# Out:
#          application_id  user_id  birth_year  gender         insert_time  \
# 7               1146166   588743      1992.0     0.0 2022-06-07 17:19:33
# 23              1237618   717213      1986.0     1.0 2022-06-07 03:26:54
# 25               272600   754046      1980.0     1.0 2022-06-07 19:24:28
# 37               703129   324991      1994.0     0.0 2022-06-07 11:12:24
# 48               612258    59149      1998.0     1.0 2022-06-07 07:31:21
# ...                 ...      ...         ...     ...                 ...
# 1394184         1107103   162983      1978.0     1.0 2022-03-22 12:14:17
# 1394203          943512   183117      1996.0     0.0 2022-03-22 16:22:21
# 1394204         1663661   183117      1996.0     0.0 2022-03-22 17:37:49
# 1394211         1864587   489900      2000.0     1.0 2022-03-22 14:55:32
# 1394215          816537     3864      1977.0     0.0 2022-03-22 08:55:14
#
#          credit_score  yearly_income      income_type company_enter_month  \
# 7               750.0     46000000.0     EARNEDINCOME          2015-10-01
# 23              530.0     51000000.0     EARNEDINCOME          2017-05-01
# 25                NaN     22000000.0     EARNEDINCOME          2009-01-01
# 37              950.0            0.0      OTHERINCOME                 NaT
# 48                NaN            0.0  PRIVATEBUSINESS          2022-03-01
# ...               ...            ...              ...                 ...
# 1394184         750.0     55000000.0     EARNEDINCOME          2014-08-01
# 1394203         710.0     24000000.0     EARNEDINCOME          2022-01-01
# 1394204         710.0     30000000.0      OTHERINCOME                 NaT
# 1394211         590.0     25000000.0       FREELANCER          2021-06-01
# 1394215           NaN     35000000.0       FREELANCER          2011-03-01
#
#         employment_type houseown_type  desired_amount purpose  \
# 7                   정규직        기타가족소유       6000000.0     생활비
# 23                  정규직           전월세       5000000.0     생활비
# 25                  정규직           전월세      22000000.0    대환대출
# 37                   기타            자가      50000000.0      기타
# 48                   기타           전월세       1000000.0     생활비
# ...                 ...           ...             ...     ...
# 1394184             정규직           전월세      50000000.0     생활비
# 1394203             정규직           전월세      25000000.0  전월세보증금
# 1394204              기타           전월세      25000000.0      기타
# 1394211              기타        기타가족소유       5000000.0    사업자금
# 1394215              기타            자가      20000000.0     생활비
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 7                               0.0                                  0.0
# 23                              0.0                                  0.0
# 25                              0.0                                  NaN
# 37                              0.0                                  NaN
# 48                              0.0                                  0.0
# ...                             ...                                  ...
# 1394184                         NaN                                  NaN
# 1394203                         NaN                                  NaN
# 1394204                         NaN                                  NaN
# 1394211                         NaN                                  NaN
# 1394215                         NaN                                  NaN
#
#          existing_loan_cnt  existing_loan_amt
# 7                      NaN                NaN
# 23                     NaN                NaN
# 25                     NaN                NaN
# 37                     NaN                NaN
# 48                     NaN                NaN
# ...                    ...                ...
# 1394184                NaN                NaN
# 1394203                NaN                NaN
# 1394204                NaN                NaN
# 1394211                NaN                NaN
# 1394215                NaN                NaN
#
# [198556 rows x 17 columns]

# %%
user_spec[(user_spec["existing_loan_cnt"].isna()) & (user_spec["existing_loan_amt"].isna())]
# Out:
#          application_id  user_id  birth_year  gender         insert_time  \
# 7               1146166   588743      1992.0     0.0 2022-06-07 17:19:33
# 23              1237618   717213      1986.0     1.0 2022-06-07 03:26:54
# 25               272600   754046      1980.0     1.0 2022-06-07 19:24:28
# 37               703129   324991      1994.0     0.0 2022-06-07 11:12:24
# 48               612258    59149      1998.0     1.0 2022-06-07 07:31:21
# ...                 ...      ...         ...     ...                 ...
# 1394184         1107103   162983      1978.0     1.0 2022-03-22 12:14:17
# 1394203          943512   183117      1996.0     0.0 2022-03-22 16:22:21
# 1394204         1663661   183117      1996.0     0.0 2022-03-22 17:37:49
# 1394211         1864587   489900      2000.0     1.0 2022-03-22 14:55:32
# 1394215          816537     3864      1977.0     0.0 2022-03-22 08:55:14
#
#          credit_score  yearly_income      income_type company_enter_month  \
# 7               750.0     46000000.0     EARNEDINCOME          2015-10-01
# 23              530.0     51000000.0     EARNEDINCOME          2017-05-01
# 25                NaN     22000000.0     EARNEDINCOME          2009-01-01
# 37              950.0            0.0      OTHERINCOME                 NaT
# 48                NaN            0.0  PRIVATEBUSINESS          2022-03-01
# ...               ...            ...              ...                 ...
# 1394184         750.0     55000000.0     EARNEDINCOME          2014-08-01
# 1394203         710.0     24000000.0     EARNEDINCOME          2022-01-01
# 1394204         710.0     30000000.0      OTHERINCOME                 NaT
# 1394211         590.0     25000000.0       FREELANCER          2021-06-01
# 1394215           NaN     35000000.0       FREELANCER          2011-03-01
#
#         employment_type houseown_type  desired_amount purpose  \
# 7                   정규직        기타가족소유       6000000.0     생활비
# 23                  정규직           전월세       5000000.0     생활비
# 25                  정규직           전월세      22000000.0    대환대출
# 37                   기타            자가      50000000.0      기타
# 48                   기타           전월세       1000000.0     생활비
# ...                 ...           ...             ...     ...
# 1394184             정규직           전월세      50000000.0     생활비
# 1394203             정규직           전월세      25000000.0  전월세보증금
# 1394204              기타           전월세      25000000.0      기타
# 1394211              기타        기타가족소유       5000000.0    사업자금
# 1394215              기타            자가      20000000.0     생활비
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 7                               0.0                                  0.0
# 23                              0.0                                  0.0
# 25                              0.0                                  NaN
# 37                              0.0                                  NaN
# 48                              0.0                                  0.0
# ...                             ...                                  ...
# 1394184                         NaN                                  NaN
# 1394203                         NaN                                  NaN
# 1394204                         NaN                                  NaN
# 1394211                         NaN                                  NaN
# 1394215                         NaN                                  NaN
#
#          existing_loan_cnt  existing_loan_amt
# 7                      NaN                NaN
# 23                     NaN                NaN
# 25                     NaN                NaN
# 37                     NaN                NaN
# 48                     NaN                NaN
# ...                    ...                ...
# 1394184                NaN                NaN
# 1394203                NaN                NaN
# 1394204                NaN                NaN
# 1394211                NaN                NaN
# 1394215                NaN                NaN
#
# [198556 rows x 17 columns]

# %%
user_spec[(-user_spec["existing_loan_cnt"].isna()) & (user_spec["existing_loan_amt"].isna())]["existing_loan_cnt"].value_counts()
# Out:
# 1.0    115218
# Name: existing_loan_cnt, dtype: int64

# %%
user_spec[user_spec["existing_loan_amt"] == 0]["existing_loan_cnt"].value_counts()
# Out:
# 1.0     4636
# 2.0      409
# 3.0       68
# 4.0       11
# 13.0       3
# 6.0        1
# 5.0        1
# 9.0        1
# Name: existing_loan_cnt, dtype: int64

# %% [markdown]
# ## user_spec 결측치 대체

# %% [markdown]
# #### 출생년도, 성별 결측치 대체

# %%
for i in tqdm_notebook(user_spec[user_spec["birth_year"].isna()].index):
    user_spec.loc[i,"birth_year"] = user_spec.loc[user_spec["user_id"] == user_spec.loc[i,"user_id"],"birth_year"].mean()
    user_spec.loc[i,"gender"] = user_spec.loc[user_spec["user_id"] == user_spec.loc[i,"user_id"],"gender"].mean()

user_spec.isna().sum()
# Out:
# <ipython-input-46-50dd04275f99>:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(user_spec[user_spec["birth_year"].isna()].index):
#   0%|          | 0/12961 [00:00<?, ?it/s]
# application_id                               0
# user_id                                      0
# birth_year                                9724
# gender                                    9724
# insert_time                                  0
# credit_score                            105115
# yearly_income                               90
# income_type                                 85
# company_enter_month                     171760
# employment_type                             85
# houseown_type                               85
# desired_amount                              85
# purpose                                     85
# personal_rehabilitation_yn              587461
# personal_rehabilitation_complete_yn    1203354
# existing_loan_cnt                       198556
# existing_loan_amt                       313774
# dtype: int64

# %%
np.sum(-user_spec["birth_year"].isna()) # 이정도면 na를 보함하여 범주화 해보자
# Out:
# 1384492

# %%
user_spec["birth_year"].hist()
# Out:
# <AxesSubplot:>

# %%
user_spec["only_age"] = 2022 - user_spec["birth_year"]

# %%
#만으로 청소년(13~18세) · 청년(19~29세) · 중년(30~49세) · 장년(50~64세) · 노년(65세 이상)

# %%
user_spec["cat_age"] =  pd.cut(user_spec["only_age"],[12,18, 29, 49, 64,100], right=False, labels=['청소년', '청년', '중년', '장년', '노년']).astype(object)
user_spec["cat_age"]
# Out:
# 0          중년
# 1          장년
# 2          청년
# 3          중년
# 4          청년
#            ..
# 1394211    청년
# 1394212    노년
# 1394213    중년
# 1394214    중년
# 1394215    중년
# Name: cat_age, Length: 1394216, dtype: object

# %%
user_spec.loc[user_spec["cat_age"].isna(),"cat_age"] = "Missing_age"

# %%
user_spec["cat_age"].value_counts()
# Out:
# 중년             866360
# 청년             261849
# 장년             228705
# 노년              27521
# Missing_age      9724
# 청소년                57
# Name: cat_age, dtype: int64

# %%
user_spec["cat_gender"] = "Missing_gender"
user_spec.loc[user_spec["gender"] == 1,"cat_gender"] = "남성"
user_spec.loc[user_spec["gender"] == 0,"cat_gender"] = "여성"

# %%
user_spec.value_counts(["cat_age","cat_gender"]).reset_index()
# Out:
#         cat_age      cat_gender       0
# 0            중년              남성  587014
# 1            중년              여성  279346
# 2            청년              남성  185929
# 3            장년              남성  148260
# 4            장년              여성   80445
# 5            청년              여성   75920
# 6            노년              남성   15084
# 7            노년              여성   12437
# 8   Missing_age  Missing_gender    9724
# 9           청소년              남성      41
# 10          청소년              여성      16

# %% [markdown]
# #### yearly_income (연소득), income_type , employment_type, houseown_type , desired_amount, purpose 결측치 대체

# %% [markdown]
# yearly_income 기준 삭제
#
# 그 전에 application_id 341149는 loan_result에 존재함.

# %%
user_spec[user_spec["user_id"] == 670502]
# Out:
#         application_id  user_id  birth_year  gender         insert_time  \
# 566158         1746224   670502      1981.0     1.0 2022-06-30 22:41:11
# 597613          341149   670502      1981.0     1.0 2022-06-30 21:32:18
#
#         credit_score  yearly_income  income_type company_enter_month  \
# 566158         930.0            0.0  OTHERINCOME                 NaT
# 597613         930.0            NaN  OTHERINCOME                 NaT
#
#        employment_type houseown_type  desired_amount purpose  \
# 566158              기타        기타가족소유       6000000.0    사업자금
# 597613              기타        기타가족소유       6000000.0    사업자금
#
#         personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 566158                         0.0                                  0.0
# 597613                         0.0                                  0.0
#
#         existing_loan_cnt  existing_loan_amt  only_age cat_age cat_gender
# 566158                1.0          3000000.0      41.0      중년         남성
# 597613                1.0          3000000.0      41.0      중년         남성

# %%
#같은 user의 다른 application을 이용하여 대체, 생성일시를 제외한 모든 조건이 동일하기 때문에 연소득 대체 가능하다고 판단
user_spec.loc[user_spec["application_id"] == 341149, "yearly_income"] = user_spec.loc[user_spec["user_id"] == 670502,"yearly_income"].mean()

# %%
user_spec = user_spec[-user_spec["yearly_income"].isna()]

# %% [markdown]
# #### 입사년도 결측치 대체

# %%
#user_id별로 company_enter_month 종류
user_spec[-user_spec["company_enter_month"].isna()].groupby('user_id')['company_enter_month'].nunique().sort_values(ascending = False)[0:20]
# Out:
# user_id
# 806361    30
# 132604    16
# 783956    13
# 292140    13
# 260768    12
# 634579    12
# 757883    12
# 436430    12
# 196512    11
# 305961    11
# 868369    11
# 591201    11
# 810420    10
# 224561    10
# 111290    10
# 278556    10
# 733252    10
# 23867     10
# 631410    10
# 419084     9
# Name: company_enter_month, dtype: int64

# %%
user_spec[user_spec["user_id"]==806361]
# Out:
#         application_id  user_id  birth_year  gender         insert_time  \
# 10051           636369   806361      1973.0     0.0 2022-06-07 06:45:37
# 38391           505409   806361      1973.0     0.0 2022-06-14 15:20:29
# 39410          2066460   806361      1973.0     0.0 2022-06-16 10:28:53
# 39411           919618   806361      1973.0     0.0 2022-06-16 14:48:04
# 39782           901590   806361      1973.0     0.0 2022-04-06 14:59:51
# ...                ...      ...         ...     ...                 ...
# 930997         1508670   806361      1973.0     0.0 2022-06-07 05:42:26
# 932359         1890131   806361      1973.0     0.0 2022-06-13 11:21:24
# 932827         1657879   806361      1973.0     0.0 2022-04-03 18:47:58
# 934495          823920   806361      1973.0     0.0 2022-03-21 22:40:09
# 935630         1375725   806361      1973.0     0.0 2022-03-22 09:03:40
#
#         credit_score  yearly_income    income_type company_enter_month  \
# 10051          660.0   3.000000e+09     FREELANCER          2015-01-01
# 38391          660.0   9.500000e+09  EARNEDINCOME2          1997-05-01
# 39410          660.0   1.000000e+08    OTHERINCOME                 NaT
# 39411          660.0   9.500000e+08  EARNEDINCOME2          1997-01-01
# 39782          630.0   9.500000e+09  EARNEDINCOME2          2001-01-01
# ...              ...            ...            ...                 ...
# 930997         660.0   8.000000e+09  EARNEDINCOME2          2002-02-01
# 932359         660.0   3.000000e+08    OTHERINCOME                 NaT
# 932827         630.0   9.600000e+09  EARNEDINCOME2          2003-09-01
# 934495         700.0   9.500000e+08  EARNEDINCOME2          1997-03-01
# 935630         700.0   9.500000e+09  EARNEDINCOME2          1995-03-01
#
#        employment_type houseown_type  desired_amount purpose  \
# 10051               기타            자가       5000000.0     생활비
# 38391              정규직            자가       6000000.0     생활비
# 39410               기타            자가       6000000.0     생활비
# 39411               기타            자가      10000000.0    주택구입
# 39782              정규직            자가       7000000.0     생활비
# ...                ...           ...             ...     ...
# 930997             계약직            자가      35000000.0    사업자금
# 932359              기타            자가       2000000.0     생활비
# 932827             일용직            자가       5000000.0     생활비
# 934495             정규직            자가      35000000.0    대환대출
# 935630             정규직            자가      50000000.0   자동차구입
#
#         personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 10051                          0.0                                  NaN
# 38391                          0.0                                  NaN
# 39410                          0.0                                  NaN
# 39411                          0.0                                  NaN
# 39782                          NaN                                  NaN
# ...                            ...                                  ...
# 930997                         0.0                                  NaN
# 932359                         0.0                                  NaN
# 932827                         NaN                                  NaN
# 934495                         NaN                                  NaN
# 935630                         NaN                                  NaN
#
#         existing_loan_cnt  existing_loan_amt  only_age cat_age cat_gender
# 10051                 1.0                NaN      49.0      장년         여성
# 38391                 1.0                NaN      49.0      장년         여성
# 39410                 1.0                NaN      49.0      장년         여성
# 39411                 1.0                NaN      49.0      장년         여성
# 39782                 1.0                NaN      49.0      장년         여성
# ...                   ...                ...       ...     ...        ...
# 930997                1.0                NaN      49.0      장년         여성
# 932359                1.0                NaN      49.0      장년         여성
# 932827                1.0                NaN      49.0      장년         여성
# 934495                1.0                NaN      49.0      장년         여성
# 935630                1.0                NaN      49.0      장년         여성
#
# [88 rows x 20 columns]

# %% [markdown]
# 입사년도 종류가 30개인 미친놈 존재

# %% [markdown]
# income_type이 기타인 사용자들은 company_enter_month가 NA인 것이 당연함
#
# 하지만 그렇지 않은 사용자들은 company_enter_month가 NA인 것이 이상함

# %%
user_spec[(user_spec["company_enter_month"].isna()) & (user_spec["income_type"]!="OTHERINCOME")]
# Out:
#          application_id  user_id  birth_year  gender         insert_time  \
# 77585           1728563   759028      1962.0     1.0 2022-05-11 16:06:26
# 89830             89051   776609      1991.0     0.0 2022-06-02 19:28:01
# 167239           860275   861913      1980.0     0.0 2022-05-02 16:19:56
# 309603           478904   418233      1985.0     0.0 2022-05-15 17:40:59
# 411187           597961   851635      1971.0     0.0 2022-03-10 14:27:19
# 645702           978338   418233      1985.0     0.0 2022-04-14 18:52:19
# 658794          1024494   418233      1985.0     0.0 2022-05-16 15:28:53
# 928074           994477   546184      1981.0     0.0 2022-03-31 10:50:56
# 945656          1401966   776609      1991.0     0.0 2022-05-13 23:15:27
# 1057011         1026844   174784      1998.0     1.0 2022-04-08 15:12:08
#
#          credit_score  yearly_income      income_type company_enter_month  \
# 77585           600.0     30000000.0     EARNEDINCOME                 NaT
# 89830           800.0      2000000.0     EARNEDINCOME                 NaT
# 167239            NaN     21000000.0     EARNEDINCOME                 NaT
# 309603          690.0     50000000.0  PRIVATEBUSINESS                 NaT
# 411187          550.0     26000000.0     EARNEDINCOME                 NaT
# 645702          690.0     50000000.0  PRIVATEBUSINESS                 NaT
# 658794          690.0     50000000.0  PRIVATEBUSINESS                 NaT
# 928074            NaN     30000000.0     EARNEDINCOME                 NaT
# 945656          930.0     26000000.0     EARNEDINCOME                 NaT
# 1057011           NaN     32000000.0     EARNEDINCOME                 NaT
#
#         employment_type houseown_type  desired_amount     purpose  \
# 77585               정규직           전월세      10000000.0  SWITCHLOAN
# 89830               계약직           전월세      10000000.0         생활비
# 167239              정규직           전월세      20000000.0      LIVING
# 309603               기타           전월세      20000000.0         생활비
# 411187              정규직        기타가족소유      20000000.0      LIVING
# 645702               기타           전월세      30000000.0        사업자금
# 658794               기타           전월세      50000000.0        사업자금
# 928074              정규직        기타가족소유      10000000.0      LIVING
# 945656              계약직           전월세      10000000.0         생활비
# 1057011             정규직           전월세      10000000.0  SWITCHLOAN
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 77585                           NaN                                  NaN
# 89830                           0.0                                  0.0
# 167239                          NaN                                  NaN
# 309603                          0.0                                  0.0
# 411187                          NaN                                  NaN
# 645702                          NaN                                  NaN
# 658794                          0.0                                  0.0
# 928074                          NaN                                  NaN
# 945656                          0.0                                  0.0
# 1057011                         NaN                                  NaN
#
#          existing_loan_cnt  existing_loan_amt  only_age cat_age cat_gender
# 77585                  1.0         15000000.0      60.0      장년         남성
# 89830                  1.0                NaN      31.0      중년         여성
# 167239                 NaN                NaN      42.0      중년         여성
# 309603                 3.0         20000000.0      37.0      중년         여성
# 411187                 5.0         68000000.0      51.0      장년         여성
# 645702                 3.0         20000000.0      37.0      중년         여성
# 658794                 3.0         20000000.0      37.0      중년         여성
# 928074                 3.0         62000000.0      41.0      중년         여성
# 945656                 1.0                NaN      31.0      중년         여성
# 1057011                NaN                NaN      24.0      청년         남성

# %%
loan_result[loan_result["application_id"] == 860275]
# Out:
#           application_id loanapply_insert_time  bank_id  product_id  \
# 11273330          860275   2022-05-02 16:19:58       58         175
# 11273331          860275   2022-05-02 16:19:58        6          36
# 11273332          860275   2022-05-02 16:19:57       51         247
# 11273333          860275   2022-05-02 16:19:58       32          56
#
#           loan_limit  loan_rate  is_applied
# 11273330  11000000.0       14.8         0.0
# 11273331   8000000.0       17.7         0.0
# 11273332  25000000.0       18.9         0.0
# 11273333   5000000.0       17.7         0.0

# %%
for i in user_spec[(user_spec["company_enter_month"].isna()) & (user_spec["income_type"]!="OTHERINCOME")]["user_id"]:
    print(i,":", sum(user_spec["user_id"] == i))
# Out:
# 759028 : 4
# 776609 : 2
# 861913 : 1
# 418233 : 3
# 851635 : 1
# 418233 : 3
# 418233 : 3
# 546184 : 2
# 776609 : 2
# 174784 : 1

# %%
user_spec[user_spec["user_id"] == 759028]
# Out:
#          application_id  user_id  birth_year  gender         insert_time  \
# 77585           1728563   759028      1962.0     1.0 2022-05-11 16:06:26
# 101410          1176623   759028      1962.0     1.0 2022-04-27 11:45:40
# 886336           693346   759028      1962.0     1.0 2022-06-30 11:05:37
# 1357869          637591   759028      1962.0     1.0 2022-03-04 15:53:19
#
#          credit_score  yearly_income   income_type company_enter_month  \
# 77585           600.0     30000000.0  EARNEDINCOME                 NaT
# 101410          600.0     24000000.0  EARNEDINCOME          2021-10-01
# 886336          580.0     30000000.0  EARNEDINCOME          2021-09-01
# 1357869           NaN     26000000.0  EARNEDINCOME          2021-10-01
#
#         employment_type houseown_type  desired_amount     purpose  \
# 77585               정규직           전월세      10000000.0  SWITCHLOAN
# 101410              정규직            자가      15000000.0        대환대출
# 886336              정규직        기타가족소유      16000000.0         생활비
# 1357869             정규직            자가      10000000.0         생활비
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 77585                           NaN                                  NaN
# 101410                          0.0                                  NaN
# 886336                          0.0                                  0.0
# 1357869                         NaN                                  NaN
#
#          existing_loan_cnt  existing_loan_amt  only_age cat_age cat_gender
# 77585                  1.0         15000000.0      60.0      장년         남성
# 101410                 1.0         15000000.0      60.0      장년         남성
# 886336                 1.0         15000000.0      60.0      장년         남성
# 1357869                1.0         15000000.0      60.0      장년         남성

# %%
for i in user_spec[(user_spec["company_enter_month"].isna()) & (user_spec["income_type"]!="OTHERINCOME")]["application_id"]:
    print(i,":", sum(loan_result["application_id"] == i))
# Out:
# 1728563 : 0
# 89051 : 23
# 860275 : 4
# 478904 : 7
# 597961 : 0
# 978338 : 9
# 1024494 : 7
# 994477 : 0
# 1401966 : 21
# 1026844 : 7

# %% [markdown]
# 소득 종류에 따라 입사년도 결측인 비율이 다름. 기타에 해당하는 주부, 학생은 입사년도가 존재하는 경우도 있음

# %%
user_spec[user_spec["company_enter_month"].isna()].value_counts("income_type")
# Out:
# income_type
# OTHERINCOME        171662
# EARNEDINCOME            7
# PRIVATEBUSINESS         3
# dtype: int64

# %%
aa = user_spec[user_spec["company_enter_month"].isna()]
aa[aa["income_type"]=="EARNEDINCOME"]
# Out:
#          application_id  user_id  birth_year  gender         insert_time  \
# 77585           1728563   759028      1962.0     1.0 2022-05-11 16:06:26
# 89830             89051   776609      1991.0     0.0 2022-06-02 19:28:01
# 167239           860275   861913      1980.0     0.0 2022-05-02 16:19:56
# 411187           597961   851635      1971.0     0.0 2022-03-10 14:27:19
# 928074           994477   546184      1981.0     0.0 2022-03-31 10:50:56
# 945656          1401966   776609      1991.0     0.0 2022-05-13 23:15:27
# 1057011         1026844   174784      1998.0     1.0 2022-04-08 15:12:08
#
#          credit_score  yearly_income   income_type company_enter_month  \
# 77585           600.0     30000000.0  EARNEDINCOME                 NaT
# 89830           800.0      2000000.0  EARNEDINCOME                 NaT
# 167239            NaN     21000000.0  EARNEDINCOME                 NaT
# 411187          550.0     26000000.0  EARNEDINCOME                 NaT
# 928074            NaN     30000000.0  EARNEDINCOME                 NaT
# 945656          930.0     26000000.0  EARNEDINCOME                 NaT
# 1057011           NaN     32000000.0  EARNEDINCOME                 NaT
#
#         employment_type houseown_type  desired_amount     purpose  \
# 77585               정규직           전월세      10000000.0  SWITCHLOAN
# 89830               계약직           전월세      10000000.0         생활비
# 167239              정규직           전월세      20000000.0      LIVING
# 411187              정규직        기타가족소유      20000000.0      LIVING
# 928074              정규직        기타가족소유      10000000.0      LIVING
# 945656              계약직           전월세      10000000.0         생활비
# 1057011             정규직           전월세      10000000.0  SWITCHLOAN
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 77585                           NaN                                  NaN
# 89830                           0.0                                  0.0
# 167239                          NaN                                  NaN
# 411187                          NaN                                  NaN
# 928074                          NaN                                  NaN
# 945656                          0.0                                  0.0
# 1057011                         NaN                                  NaN
#
#          existing_loan_cnt  existing_loan_amt  only_age cat_age cat_gender
# 77585                  1.0         15000000.0      60.0      장년         남성
# 89830                  1.0                NaN      31.0      중년         여성
# 167239                 NaN                NaN      42.0      중년         여성
# 411187                 5.0         68000000.0      51.0      장년         여성
# 928074                 3.0         62000000.0      41.0      중년         여성
# 945656                 1.0                NaN      31.0      중년         여성
# 1057011                NaN                NaN      24.0      청년         남성

# %%
aa[aa["income_type"]=="PRIVATEBUSINESS"]
# Out:
#         application_id  user_id  birth_year  gender         insert_time  \
# 309603          478904   418233      1985.0     0.0 2022-05-15 17:40:59
# 645702          978338   418233      1985.0     0.0 2022-04-14 18:52:19
# 658794         1024494   418233      1985.0     0.0 2022-05-16 15:28:53
#
#         credit_score  yearly_income      income_type company_enter_month  \
# 309603         690.0     50000000.0  PRIVATEBUSINESS                 NaT
# 645702         690.0     50000000.0  PRIVATEBUSINESS                 NaT
# 658794         690.0     50000000.0  PRIVATEBUSINESS                 NaT
#
#        employment_type houseown_type  desired_amount purpose  \
# 309603              기타           전월세      20000000.0     생활비
# 645702              기타           전월세      30000000.0    사업자금
# 658794              기타           전월세      50000000.0    사업자금
#
#         personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 309603                         0.0                                  0.0
# 645702                         NaN                                  NaN
# 658794                         0.0                                  0.0
#
#         existing_loan_cnt  existing_loan_amt  only_age cat_age cat_gender
# 309603                3.0         20000000.0      37.0      중년         여성
# 645702                3.0         20000000.0      37.0      중년         여성
# 658794                3.0         20000000.0      37.0      중년         여성

# %% [markdown]
# #### personal_rehabilitation_yn, personal_rehabilitation_complete_yn
#
# - 개인 회생자 신청 여부(0:개인회생자 X, 1:개인회생자O)
# - 개인 회생 완료 여부(personal_rehabilitation_yn == 1인 사람들 중, 0:납입중, 1:완료)
#
# (0,NA)
# (1,0)
# (1,1)

# %%
print("1,NA :",user_spec[(user_spec["personal_rehabilitation_yn"] == 1) & (user_spec["personal_rehabilitation_complete_yn"].isna())].shape)
print("1,0 or 1,1 :",user_spec[(user_spec["personal_rehabilitation_yn"] == 1) & (-user_spec["personal_rehabilitation_complete_yn"].isna())].shape)
print("0,NA :",user_spec[(user_spec["personal_rehabilitation_yn"] == 0) & (user_spec["personal_rehabilitation_complete_yn"].isna())].shape)
print("0,0 or 0,1 :",user_spec[(user_spec["personal_rehabilitation_yn"] == 0) & (-user_spec["personal_rehabilitation_complete_yn"].isna())].shape)
# Out:
# 1,NA : (0, 20)
# 1,0 or 1,1 : (12709, 20)
# 0,NA : (615893, 20)
# 0,0 or 0,1 : (178149, 20)

# %% [markdown]
# 0,0 or 0,1 는 아마도 개인회생자 여부를 체크 한 후, 다시 해제한 경우일 가능성이 있음!
#
# -> 그렇다면 전부 0, NA로 대체하는 것이 옳음

# %%
user_spec.loc[(user_spec["personal_rehabilitation_yn"] == 0) & (-user_spec["personal_rehabilitation_complete_yn"].isna()), "personal_rehabilitation_complete_yn"] = np.nan

# %%
print("1,NA :",user_spec[(user_spec["personal_rehabilitation_yn"] == 1) & (user_spec["personal_rehabilitation_complete_yn"].isna())].shape)
print("1,0 or 1,1 :",user_spec[(user_spec["personal_rehabilitation_yn"] == 1) & (-user_spec["personal_rehabilitation_complete_yn"].isna())].shape)
print("0,NA :",user_spec[(user_spec["personal_rehabilitation_yn"] == 0) & (user_spec["personal_rehabilitation_complete_yn"].isna())].shape)
print("0,0 or 0,1 :",user_spec[(user_spec["personal_rehabilitation_yn"] == 0) & (-user_spec["personal_rehabilitation_complete_yn"].isna())].shape)
# Out:
# 1,NA : (0, 20)
# 1,0 or 1,1 : (12709, 20)
# 0,NA : (794042, 20)
# 0,0 or 0,1 : (0, 20)

# %% [markdown]
# 범주화

# %%
user_spec["rehabilitation"] = "rehabilitation_not"

# %%
user_spec.loc[(user_spec["personal_rehabilitation_yn"] == 1) & (user_spec["personal_rehabilitation_complete_yn"] == 0),"rehabilitation"] = "rehabilitation"
user_spec.loc[(user_spec["personal_rehabilitation_yn"] == 1) & (user_spec["personal_rehabilitation_complete_yn"] == 1),"rehabilitation"] = "rehabilitation_completed"

# %%
user_spec["rehabilitation"].value_counts()
# Out:
# rehabilitation_not          1381418
# rehabilitation                11361
# rehabilitation_completed       1348
# Name: rehabilitation, dtype: int64

# %% [markdown]
# #### existing_loan_cnt, existing_loan_amt 결측치 대체

# %% [markdown]
# existing_loan_cnt, existing_loan_amt가 결측인 행의 유저가 다른 행에서는 결측이 아닌 행이 있는지 확인

# %%
n1 = 0
n2 = 0
for i in tqdm_notebook(user_spec[(user_spec["existing_loan_cnt"].isna()) & (user_spec["existing_loan_amt"].isna())]["user_id"]):
    n1 += (len(user_spec[user_spec["user_id"] == i]) != sum(user_spec[user_spec["user_id"] == i]["existing_loan_cnt"].isna()))
    n2 += (len(user_spec[user_spec["user_id"] == i]) != sum(user_spec[user_spec["user_id"] == i]["existing_loan_amt"].isna()))
# Out:
# <ipython-input-75-e6bc07e5f9ce>:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(user_spec[(user_spec["existing_loan_cnt"].isna()) & (user_spec["existing_loan_amt"].isna())]["user_id"]):
#   0%|          | 0/198539 [00:00<?, ?it/s]

# %%
print(n1)
print(n2)
# Out:
# 0
# 0

# %% [markdown]
# 해당 유저는 기대출이 없는 유저로 판단
#
# 추가로 기대출 수는 NA가 아니지만, 기대출 금액은 NA인 행에 대하여 같은 user_id를 가진 행 중에 기대출 금액이 NA가 아닌 행이 존재하는지 확인

# %%
n3 = 0
for i in tqdm_notebook(user_spec[-(user_spec["existing_loan_cnt"].isna()) & (user_spec["existing_loan_amt"].isna())]["user_id"]):
    n3 += (len(user_spec[user_spec["user_id"] == i]) != sum(user_spec[user_spec["user_id"] == i]["existing_loan_amt"].isna()))
# Out:
# <ipython-input-77-b1df4c054bbb>:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(user_spec[-(user_spec["existing_loan_cnt"].isna()) & (user_spec["existing_loan_amt"].isna())]["user_id"]):
#   0%|          | 0/115212 [00:00<?, ?it/s]

# %%
print(n3)
# Out:
# 0

# %% [markdown]
# 기대출 횟수와 잔액의 NA여부를 바탕으로 그룹 형성
#
# - 횟수가 0인 경우는 없음
# - 잔액이 NA인 경우는 횟수가 NA또는 1
# - 잔액이 0인 경우 존재

# %%
loan_notna_na = user_spec[-(user_spec["existing_loan_cnt"].isna()) & (user_spec["existing_loan_amt"].isna())]
loan_notna_na.value_counts("existing_loan_cnt")
# Out:
# existing_loan_cnt
# 1.0    115212
# dtype: int64

# %%
loan_notna_0 = user_spec[-(user_spec["existing_loan_cnt"].isna()) & (user_spec["existing_loan_amt"]==0)]
loan_notna_0.value_counts("existing_loan_cnt")
# Out:
# existing_loan_cnt
# 1.0     4636
# 2.0      409
# 3.0       68
# 4.0       11
# 13.0       3
# 5.0        1
# 6.0        1
# 9.0        1
# dtype: int64

# %%
loan_na_na = user_spec[(user_spec["existing_loan_cnt"].isna()) & (user_spec["existing_loan_amt"].isna())]
loan_na_na.value_counts("existing_loan_cnt")
# Out:
# Series([], dtype: int64)

# %%
loan_notna_notna = user_spec[-(user_spec["existing_loan_cnt"].isna()) & -(user_spec["existing_loan_amt"].isna())]

# %%
loan_notna_na.value_counts("rehabilitation")
# Out:
# rehabilitation
# rehabilitation_not          113540
# rehabilitation                1332
# rehabilitation_completed       340
# dtype: int64

# %%
loan_notna_na["yearly_income"].min()
# Out:
# 0.0

# %%
loan_na_na["yearly_income"].min()
# Out:
# 0.0

# %%
loan_na_na[loan_na_na["yearly_income"] == 0]
# Out:
#          application_id  user_id  birth_year  gender         insert_time  \
# 37               703129   324991      1994.0     0.0 2022-06-07 11:12:24
# 48               612258    59149      1998.0     1.0 2022-06-07 07:31:21
# 433             1162413    69770      2001.0     1.0 2022-03-29 10:17:25
# 732             1093124   431380      1972.0     0.0 2022-03-11 10:54:37
# 966             2148249   155244      1999.0     1.0 2022-05-31 19:38:44
# ...                 ...      ...         ...     ...                 ...
# 1393882         1476366   205693      1997.0     0.0 2022-06-26 11:21:32
# 1393889          126771   501037         NaN     NaN 2022-06-26 13:34:45
# 1393892         1168646   376368      1988.0     0.0 2022-06-26 16:26:13
# 1393898         1762801   792309      2001.0     1.0 2022-06-26 10:56:22
# 1393925          724590   250369      1967.0     1.0 2022-06-26 10:37:22
#
#          credit_score  yearly_income      income_type company_enter_month  \
# 37              950.0            0.0      OTHERINCOME                 NaT
# 48                NaN            0.0  PRIVATEBUSINESS          2022-03-01
# 433             650.0            0.0      OTHERINCOME                 NaT
# 732               NaN            0.0  PRIVATEBUSINESS          2021-06-01
# 966               NaN            0.0      OTHERINCOME                 NaT
# ...               ...            ...              ...                 ...
# 1393882         750.0            0.0      OTHERINCOME                 NaT
# 1393889        1000.0            0.0      OTHERINCOME                 NaT
# 1393892         600.0            0.0       FREELANCER          2021-11-01
# 1393898           NaN            0.0      OTHERINCOME                 NaT
# 1393925         940.0            0.0      OTHERINCOME                 NaT
#
#         employment_type  ... personal_rehabilitation_yn  \
# 37                   기타  ...                        0.0
# 48                   기타  ...                        0.0
# 433                  기타  ...                        NaN
# 732                  기타  ...                        NaN
# 966                  기타  ...                        0.0
# ...                 ...  ...                        ...
# 1393882              기타  ...                        0.0
# 1393889              기타  ...                        0.0
# 1393892              기타  ...                        0.0
# 1393898              기타  ...                        0.0
# 1393925              기타  ...                        0.0
#
#          personal_rehabilitation_complete_yn existing_loan_cnt  \
# 37                                       NaN               NaN
# 48                                       NaN               NaN
# 433                                      NaN               NaN
# 732                                      NaN               NaN
# 966                                      NaN               NaN
# ...                                      ...               ...
# 1393882                                  NaN               NaN
# 1393889                                  NaN               NaN
# 1393892                                  NaN               NaN
# 1393898                                  NaN               NaN
# 1393925                                  NaN               NaN
#
#          existing_loan_amt  only_age      cat_age      cat_gender  \
# 37                     NaN      28.0           청년              여성
# 48                     NaN      24.0           청년              남성
# 433                    NaN      21.0           청년              남성
# 732                    NaN      50.0           장년              여성
# 966                    NaN      23.0           청년              남성
# ...                    ...       ...          ...             ...
# 1393882                NaN      25.0           청년              여성
# 1393889                NaN       NaN  Missing_age  Missing_gender
# 1393892                NaN      34.0           중년              여성
# 1393898                NaN      21.0           청년              남성
# 1393925                NaN      55.0           장년              남성
#
#              rehabilitation loan_cnt loan_amt
# 37       rehabilitation_not      0.0      0.0
# 48       rehabilitation_not      0.0      0.0
# 433      rehabilitation_not      0.0      0.0
# 732      rehabilitation_not      0.0      0.0
# 966      rehabilitation_not      0.0      0.0
# ...                     ...      ...      ...
# 1393882  rehabilitation_not      0.0      0.0
# 1393889  rehabilitation_not      0.0      0.0
# 1393892  rehabilitation_not      0.0      0.0
# 1393898  rehabilitation_not      0.0      0.0
# 1393925  rehabilitation_not      0.0      0.0
#
# [4857 rows x 23 columns]

# %%
loan_na_na.value_counts("rehabilitation")
# Out:
# rehabilitation
# rehabilitation_not          196039
# rehabilitation                2316
# rehabilitation_completed       184
# dtype: int64

# %%
user_spec[user_spec["existing_loan_cnt"] == 0]
# Out:
# Empty DataFrame
# Columns: [application_id, user_id, birth_year, gender, insert_time, credit_score, yearly_income, income_type, company_enter_month, employment_type, houseown_type, desired_amount, purpose, personal_rehabilitation_yn, personal_rehabilitation_complete_yn, existing_loan_cnt, existing_loan_amt, only_age, cat_age, cat_gender, rehabilitation, loan_cnt, loan_amt]
# Index: []
#
# [0 rows x 23 columns]

# %%
user_spec[(-user_spec["existing_loan_cnt"].isna()) & (-user_spec["existing_loan_amt"].isna())]
# Out:
#          application_id  user_id  birth_year  gender         insert_time  \
# 0               1249046   118218      1985.0     1.0 2022-06-07 06:28:18
# 1                954900   553686      1968.0     1.0 2022-06-07 14:29:03
# 2                137274    59516      1997.0     1.0 2022-06-07 21:40:22
# 3               1570936   167320      1989.0     1.0 2022-06-07 09:40:27
# 4                967833    33400      2000.0     1.0 2022-06-07 08:55:07
# ...                 ...      ...         ...     ...                 ...
# 1394207         1335338   574445      1962.0     1.0 2022-03-22 16:21:41
# 1394208         1832827   546472      1993.0     1.0 2022-03-22 11:53:29
# 1394209          256365   762698      1994.0     1.0 2022-03-22 14:42:04
# 1394213         1319606   173524      1983.0     1.0 2022-03-22 07:34:32
# 1394214         1482466   766546      1975.0     1.0 2022-03-22 22:12:35
#
#          credit_score  yearly_income      income_type company_enter_month  \
# 0               660.0    108000000.0  PRIVATEBUSINESS          2015-11-01
# 1               870.0     30000000.0  PRIVATEBUSINESS          2007-02-01
# 2               710.0     30000000.0       FREELANCER          2021-09-01
# 3               820.0     62000000.0     EARNEDINCOME          2017-01-01
# 4               630.0     36000000.0     EARNEDINCOME          2021-09-01
# ...               ...            ...              ...                 ...
# 1394207         660.0     22000000.0     EARNEDINCOME          2020-12-01
# 1394208         710.0     26000000.0     EARNEDINCOME          2021-12-01
# 1394209         640.0     12000000.0     EARNEDINCOME          2021-02-01
# 1394213         750.0     75000000.0     EARNEDINCOME          2009-08-01
# 1394214         640.0     50000000.0     EARNEDINCOME          2017-05-01
#
#         employment_type  ... personal_rehabilitation_yn  \
# 0                    기타  ...                        0.0
# 1                   정규직  ...                        0.0
# 2                    기타  ...                        0.0
# 3                   정규직  ...                        0.0
# 4                   정규직  ...                        0.0
# ...                 ...  ...                        ...
# 1394207             정규직  ...                        NaN
# 1394208             정규직  ...                        NaN
# 1394209             일용직  ...                        NaN
# 1394213             정규직  ...                        NaN
# 1394214             정규직  ...                        NaN
#
#          personal_rehabilitation_complete_yn existing_loan_cnt  \
# 0                                        NaN               4.0
# 1                                        NaN               1.0
# 2                                        NaN               5.0
# 3                                        NaN               7.0
# 4                                        NaN               1.0
# ...                                      ...               ...
# 1394207                                  NaN               5.0
# 1394208                                  NaN               2.0
# 1394209                                  NaN               6.0
# 1394213                                  NaN               8.0
# 1394214                                  NaN              10.0
#
#          existing_loan_amt  only_age  cat_age  cat_gender      rehabilitation  \
# 0              162000000.0      37.0       중년          남성  rehabilitation_not
# 1               27000000.0      54.0       장년          남성  rehabilitation_not
# 2               15000000.0      25.0       청년          남성  rehabilitation_not
# 3              344000000.0      33.0       중년          남성  rehabilitation_not
# 4               16000000.0      22.0       청년          남성  rehabilitation_not
# ...                    ...       ...      ...         ...                 ...
# 1394207        102000000.0      60.0       장년          남성  rehabilitation_not
# 1394208          7000000.0      29.0       중년          남성  rehabilitation_not
# 1394209         76000000.0      28.0       청년          남성  rehabilitation_not
# 1394213        200000000.0      39.0       중년          남성  rehabilitation_not
# 1394214        117000000.0      47.0       중년          남성  rehabilitation_not
#
#         loan_cnt     loan_amt
# 0            4.0  162000000.0
# 1            1.0   27000000.0
# 2            5.0   15000000.0
# 3            7.0  344000000.0
# 4            1.0   16000000.0
# ...          ...          ...
# 1394207      5.0  102000000.0
# 1394208      2.0    7000000.0
# 1394209      6.0   76000000.0
# 1394213      8.0  200000000.0
# 1394214     10.0  117000000.0
#
# [1080376 rows x 23 columns]

# %%
len(loan_na_na)
# Out:
# 198539

# %% [markdown]
# 기대출 횟수가 1이고 잔액이 NA이거나, 기대출 횟수가 NA이고 잔액이 NA인 경우는 최저연령이 만 14세

# %%
user_spec["only_age"].min()
# Out:
# 14.0

# %%
loan_notna_0["only_age"].min()
# Out:
# 14.0

# %%
loan_na_na["only_age"].min()
# Out:
# 14.0

# %% [markdown]
# 기대출 횟수가 NA가 아니지만, 기대출 잔액이 0인 경우는 최저연령이 만 19세이다.

# %%
loan_notna_0["only_age"].min()
# Out:
# 19.0

# %%
user_spec[user_spec["only_age"] == 14]["purpose"]
# Out:
# 213253      기타
# 270860     생활비
# 605500      기타
# 638067     생활비
# 649038     생활비
# 1164717     기타
# 1245518     기타
# Name: purpose, dtype: object

# %%
baby = user_spec[user_spec["cat_age"] == "청소년"]
baby["purpose"].unique()
# Out:
# array(['생활비', '기타', '사업자금', '대환대출', '전월세보증금', 'BUYHOUSE'], dtype=object)

# %%
baby[baby["purpose"] == 'BUYHOUSE']
# Out:
#          application_id  user_id  birth_year  gender         insert_time  \
# 1115694         1412173   841189      2005.0     1.0 2022-03-07 18:00:47
#
#          credit_score  yearly_income   income_type company_enter_month  \
# 1115694           NaN      7000000.0  EARNEDINCOME          2001-02-01
#
#         employment_type  ... personal_rehabilitation_yn  \
# 1115694             정규직  ...                        NaN
#
#          personal_rehabilitation_complete_yn existing_loan_cnt  \
# 1115694                                  NaN               NaN
#
#          existing_loan_amt  only_age  cat_age  cat_gender      rehabilitation  \
# 1115694                NaN      17.0      청소년          남성  rehabilitation_not
#
#         loan_cnt loan_amt
# 1115694      0.0      0.0
#
# [1 rows x 23 columns]

# %%
loan_na_na["credit_score"].describe()
# Out:
# count    121232.000000
# mean        665.470998
# std         159.270887
# min          60.000000
# 25%         580.000000
# 50%         640.000000
# 75%         750.000000
# max        1000.000000
# Name: credit_score, dtype: float64

# %%
loan_notna_na["credit_score"].describe()
# Out:
# count    112818.000000
# mean        653.847081
# std         160.652877
# min         100.000000
# 25%         580.000000
# 50%         640.000000
# 75%         750.000000
# max        1000.000000
# Name: credit_score, dtype: float64

# %%
loan_notna_0["credit_score"].describe()
# Out:
# count    4988.000000
# mean      722.082999
# std       196.428333
# min       100.000000
# 25%       610.000000
# 50%       730.000000
# 75%       880.000000
# max      1000.000000
# Name: credit_score, dtype: float64

# %%
loan_notna_notna["credit_score"].describe()
# Out:
# count    1.054966e+06
# mean     6.336904e+02
# std      1.152173e+02
# min      9.000000e+01
# 25%      5.700000e+02
# 50%      6.200000e+02
# 75%      6.800000e+02
# max      1.000000e+03
# Name: credit_score, dtype: float64

# %%
user_spec0[user_spec0["application_id"] == 1412173]
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 1115694         1412173   841189      2005.0     1.0  2022-03-07 18:00:47
#
#          credit_score  yearly_income   income_type  company_enter_month  \
# 1115694           NaN      7000000.0  EARNEDINCOME             200102.0
#
#         employment_type houseown_type  desired_amount   purpose  \
# 1115694             정규직            자가     250000000.0  BUYHOUSE
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 1115694                         NaN                                  NaN
#
#          existing_loan_cnt  existing_loan_amt
# 1115694                NaN                NaN

# %%
user_spec0
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 0               1249046   118218      1985.0     1.0  2022-06-07 06:28:18
# 1                954900   553686      1968.0     1.0  2022-06-07 14:29:03
# 2                137274    59516      1997.0     1.0  2022-06-07 21:40:22
# 3               1570936   167320      1989.0     1.0  2022-06-07 09:40:27
# 4                967833    33400      2000.0     1.0  2022-06-07 08:55:07
# ...                 ...      ...         ...     ...                  ...
# 1394211         1864587   489900      2000.0     1.0  2022-03-22 14:55:32
# 1394212         1327066   151422      1955.0     1.0  2022-03-22 01:19:24
# 1394213         1319606   173524      1983.0     1.0  2022-03-22 07:34:32
# 1394214         1482466   766546      1975.0     1.0  2022-03-22 22:12:35
# 1394215          816537     3864      1977.0     0.0  2022-03-22 08:55:14
#
#          credit_score  yearly_income      income_type  company_enter_month  \
# 0               660.0    108000000.0  PRIVATEBUSINESS           20151101.0
# 1               870.0     30000000.0  PRIVATEBUSINESS           20070201.0
# 2               710.0     30000000.0       FREELANCER           20210901.0
# 3               820.0     62000000.0     EARNEDINCOME           20170101.0
# 4               630.0     36000000.0     EARNEDINCOME           20210901.0
# ...               ...            ...              ...                  ...
# 1394211         590.0     25000000.0       FREELANCER             202106.0
# 1394212         980.0     20000000.0      OTHERINCOME                  NaN
# 1394213         750.0     75000000.0     EARNEDINCOME             200908.0
# 1394214         640.0     50000000.0     EARNEDINCOME             201705.0
# 1394215           NaN     35000000.0       FREELANCER             201103.0
#
#         employment_type houseown_type  desired_amount purpose  \
# 0                    기타            자가       1000000.0      기타
# 1                   정규직        기타가족소유      30000000.0    대환대출
# 2                    기타        기타가족소유      10000000.0     생활비
# 3                   정규직            자가       2000000.0     생활비
# 4                   정규직        기타가족소유       5000000.0     생활비
# ...                 ...           ...             ...     ...
# 1394211              기타        기타가족소유       5000000.0    사업자금
# 1394212              기타            자가      50000000.0     생활비
# 1394213             정규직            자가     100000000.0    대환대출
# 1394214             정규직            자가      10000000.0    대환대출
# 1394215              기타            자가      20000000.0     생활비
#
#          personal_rehabilitation_yn  personal_rehabilitation_complete_yn  \
# 0                               0.0                                  NaN
# 1                               0.0                                  NaN
# 2                               0.0                                  NaN
# 3                               0.0                                  NaN
# 4                               0.0                                  0.0
# ...                             ...                                  ...
# 1394211                         NaN                                  NaN
# 1394212                         NaN                                  NaN
# 1394213                         NaN                                  NaN
# 1394214                         NaN                                  NaN
# 1394215                         NaN                                  NaN
#
#          existing_loan_cnt  existing_loan_amt
# 0                      4.0        162000000.0
# 1                      1.0         27000000.0
# 2                      5.0         15000000.0
# 3                      7.0        344000000.0
# 4                      1.0         16000000.0
# ...                    ...                ...
# 1394211                NaN                NaN
# 1394212                1.0                NaN
# 1394213                8.0        200000000.0
# 1394214               10.0        117000000.0
# 1394215                NaN                NaN
#
# [1394216 rows x 17 columns]

# %%
loan_result[loan_result["product_id"]==21]
# Out:
#           application_id loanapply_insert_time  bank_id  product_id  \
# 461              1029177   2022-06-07 15:29:06       51          21
# 14516             138330   2022-05-09 10:34:28       51          21
# 16728             812584   2022-05-09 10:39:50       51          21
# 45252              88338   2022-05-09 09:21:24       51          21
# 85545             522593   2022-05-12 10:02:46       51          21
# ...                  ...                   ...      ...         ...
# 13445781         2101559   2022-05-09 13:29:35       51          21
# 13508408          175654   2022-05-16 10:24:30       51          21
# 13509761          813465   2022-06-03 13:16:57       51          21
# 13516069         2010015   2022-06-03 15:52:40       51          21
# 13523827          621491   2022-06-03 17:05:01       51          21
#
#           loan_limit  loan_rate  is_applied
# 461              NaN        NaN         NaN
# 14516            NaN        NaN         1.0
# 16728            NaN        NaN         1.0
# 45252            NaN        NaN         1.0
# 85545            NaN        NaN         1.0
# ...              ...        ...         ...
# 13445781         NaN        NaN         1.0
# 13508408         NaN        NaN         1.0
# 13509761         NaN        NaN         NaN
# 13516069         NaN        NaN         NaN
# 13523827         NaN        NaN         NaN
#
# [349 rows x 7 columns]

# %%
loan_result[loan_result["loan_limit"].isna()]
# Out:
#           application_id loanapply_insert_time  bank_id  product_id  \
# 461              1029177   2022-06-07 15:29:06       51          21
# 4318             1086409   2022-06-07 18:11:31       13         262
# 6971             1193826   2022-06-07 17:13:03        1         202
# 8459              447492   2022-06-07 17:12:08       30         232
# 9220              260060   2022-06-07 11:45:43       30          85
# ...                  ...                   ...      ...         ...
# 13521728         1222550   2022-06-03 16:51:24       13         262
# 13522701          135727   2022-06-03 10:59:08       10         149
# 13523316          687402   2022-06-03 12:12:31        1         102
# 13523827          621491   2022-06-03 17:05:01       51          21
# 13526948         1719382   2022-06-03 11:31:15       13         262
#
#           loan_limit  loan_rate  is_applied
# 461              NaN        NaN         NaN
# 4318             NaN        NaN         NaN
# 6971             NaN        NaN         NaN
# 8459             NaN        NaN         NaN
# 9220             NaN        NaN         NaN
# ...              ...        ...         ...
# 13521728         NaN        NaN         NaN
# 13522701         NaN        NaN         NaN
# 13523316         NaN        NaN         NaN
# 13523827         NaN        NaN         NaN
# 13526948         NaN        NaN         NaN
#
# [7495 rows x 7 columns]

# %%
user_spec[user_spec["application_id"] == 1029177]
# Out:
#         application_id  user_id  birth_year  gender         insert_time  \
# 911644         1029177   787153      1977.0     1.0 2022-06-07 13:34:58
#
#         credit_score  yearly_income   income_type company_enter_month  \
# 911644         660.0     45000000.0  EARNEDINCOME          2022-04-01
#
#        employment_type  ... personal_rehabilitation_yn  \
# 911644             일용직  ...                        0.0
#
#         personal_rehabilitation_complete_yn existing_loan_cnt  \
# 911644                                  NaN               5.0
#
#         existing_loan_amt  only_age  cat_age  cat_gender      rehabilitation  \
# 911644         12000000.0      45.0       중년          남성  rehabilitation_not
#
#        loan_cnt    loan_amt
# 911644      5.0  12000000.0
#
# [1 rows x 23 columns]

# %%
loan_na_na[loan_na_na["cat_age"] == "청소년"]
# Out:
#          application_id  user_id  birth_year  gender         insert_time  \
# 122044           311025   779832      2006.0     1.0 2022-03-08 17:32:50
# 142639          1329068    40684      2005.0     0.0 2022-06-28 13:03:10
# 154434            17414   779832      2006.0     1.0 2022-03-08 14:37:00
# 157790           591938   798868      2007.0     1.0 2022-03-08 23:41:00
# 186027           325630   446222      2005.0     1.0 2022-04-10 09:56:22
# 213253           344496   152312      2008.0     1.0 2022-05-09 23:43:13
# 267247          1496059   227623      2007.0     1.0 2022-06-26 23:04:32
# 270860            37720   869945      2008.0     1.0 2022-06-25 15:21:27
# 377474           459489    43128      2005.0     1.0 2022-03-14 00:29:47
# 400475          1770368    93261      2007.0     1.0 2022-06-07 23:13:23
# 429919          1452660    43128      2005.0     1.0 2022-03-14 00:22:56
# 465474          1700070   134020      2007.0     0.0 2022-06-25 17:34:59
# 505350          1139819   159435      2006.0     0.0 2022-06-30 15:00:36
# 520318          1063371   451344      2005.0     1.0 2022-06-26 12:24:50
# 520627            55054   203668      2005.0     0.0 2022-03-22 17:20:53
# 555270          2071145   779832      2006.0     1.0 2022-03-08 14:40:46
# 591656           576870   275392      2005.0     0.0 2022-06-25 13:13:45
# 605500          1004197   756231      2008.0     1.0 2022-06-27 15:35:42
# 649038           372044   756231      2008.0     1.0 2022-06-27 15:29:17
# 674849          1388815   798868      2007.0     1.0 2022-03-09 00:27:56
# 744880           769803   252561      2007.0     0.0 2022-06-27 13:38:11
# 787573          2056892   306411      2006.0     1.0 2022-05-07 19:23:26
# 1044616         1708377    40684      2005.0     0.0 2022-06-28 12:58:31
# 1070055         1945598   190904      2005.0     1.0 2022-05-26 22:55:52
# 1075524           62573   505440      2007.0     0.0 2022-06-28 17:02:47
# 1115694         1412173   841189      2005.0     1.0 2022-03-07 18:00:47
# 1124351         1447869   276249      2006.0     0.0 2022-06-24 15:59:11
# 1210809          843110   520186      2005.0     1.0 2022-06-10 07:37:54
# 1220567         1473986   195637      2006.0     0.0 2022-06-26 12:16:13
# 1230783         1695084   381347      2006.0     1.0 2022-06-07 23:37:58
# 1231832          689341   296122      2006.0     1.0 2022-06-27 11:39:01
# 1325718         1374844   680641      2006.0     1.0 2022-05-12 10:09:56
#
#          credit_score  yearly_income    income_type company_enter_month  \
# 122044            NaN     50000000.0    OTHERINCOME                 NaT
# 142639            NaN            0.0    OTHERINCOME                 NaT
# 154434            NaN     40000000.0    OTHERINCOME                 NaT
# 157790            NaN            0.0    OTHERINCOME                 NaT
# 186027            NaN     10000000.0    OTHERINCOME                 NaT
# 213253            NaN      2000000.0    OTHERINCOME                 NaT
# 267247            NaN            0.0    OTHERINCOME                 NaT
# 270860            NaN            0.0    OTHERINCOME                 NaT
# 377474            NaN     40000000.0  EARNEDINCOME2          2021-10-01
# 400475            NaN            0.0    OTHERINCOME                 NaT
# 429919            NaN     12000000.0    OTHERINCOME                 NaT
# 465474            NaN            0.0    OTHERINCOME                 NaT
# 505350            NaN            0.0    OTHERINCOME                 NaT
# 520318            NaN            0.0    OTHERINCOME                 NaT
# 520627            NaN      5000000.0    OTHERINCOME                 NaT
# 555270            NaN     45000000.0    OTHERINCOME                 NaT
# 591656            NaN            0.0    OTHERINCOME                 NaT
# 605500            NaN            0.0    OTHERINCOME                 NaT
# 649038            NaN            0.0    OTHERINCOME                 NaT
# 674849            NaN            0.0    OTHERINCOME                 NaT
# 744880            NaN            0.0    OTHERINCOME                 NaT
# 787573            NaN            0.0    OTHERINCOME                 NaT
# 1044616           NaN            0.0    OTHERINCOME                 NaT
# 1070055           NaN      1000000.0    OTHERINCOME                 NaT
# 1075524           NaN            0.0    OTHERINCOME                 NaT
# 1115694           NaN      7000000.0   EARNEDINCOME          2001-02-01
# 1124351           NaN            0.0    OTHERINCOME                 NaT
# 1210809           NaN            0.0    OTHERINCOME                 NaT
# 1220567           NaN            0.0    OTHERINCOME                 NaT
# 1230783           NaN     50000000.0    OTHERINCOME                 NaT
# 1231832           NaN      1000000.0    OTHERINCOME                 NaT
# 1325718           NaN            0.0    OTHERINCOME                 NaT
#
#         employment_type  ... personal_rehabilitation_yn  \
# 122044               기타  ...                        NaN
# 142639               기타  ...                        0.0
# 154434               기타  ...                        NaN
# 157790               기타  ...                        NaN
# 186027               기타  ...                        NaN
# 213253               기타  ...                        0.0
# 267247               기타  ...                        0.0
# 270860               기타  ...                        0.0
# 377474               기타  ...                        NaN
# 400475               기타  ...                        0.0
# 429919               기타  ...                        NaN
# 465474               기타  ...                        0.0
# 505350               기타  ...                        0.0
# 520318               기타  ...                        0.0
# 520627               기타  ...                        NaN
# 555270               기타  ...                        NaN
# 591656               기타  ...                        0.0
# 605500               기타  ...                        0.0
# 649038               기타  ...                        0.0
# 674849               기타  ...                        NaN
# 744880               기타  ...                        0.0
# 787573               기타  ...                        0.0
# 1044616              기타  ...                        0.0
# 1070055              기타  ...                        0.0
# 1075524              기타  ...                        0.0
# 1115694             정규직  ...                        NaN
# 1124351              기타  ...                        0.0
# 1210809              기타  ...                        0.0
# 1220567              기타  ...                        0.0
# 1230783              기타  ...                        0.0
# 1231832              기타  ...                        1.0
# 1325718              기타  ...                        0.0
#
#          personal_rehabilitation_complete_yn existing_loan_cnt  \
# 122044                                   NaN               NaN
# 142639                                   NaN               NaN
# 154434                                   NaN               NaN
# 157790                                   NaN               NaN
# 186027                                   NaN               NaN
# 213253                                   NaN               NaN
# 267247                                   NaN               NaN
# 270860                                   NaN               NaN
# 377474                                   NaN               NaN
# 400475                                   NaN               NaN
# 429919                                   NaN               NaN
# 465474                                   NaN               NaN
# 505350                                   NaN               NaN
# 520318                                   NaN               NaN
# 520627                                   NaN               NaN
# 555270                                   NaN               NaN
# 591656                                   NaN               NaN
# 605500                                   NaN               NaN
# 649038                                   NaN               NaN
# 674849                                   NaN               NaN
# 744880                                   NaN               NaN
# 787573                                   NaN               NaN
# 1044616                                  NaN               NaN
# 1070055                                  NaN               NaN
# 1075524                                  NaN               NaN
# 1115694                                  NaN               NaN
# 1124351                                  NaN               NaN
# 1210809                                  NaN               NaN
# 1220567                                  NaN               NaN
# 1230783                                  NaN               NaN
# 1231832                                  0.0               NaN
# 1325718                                  NaN               NaN
#
#          existing_loan_amt  only_age  cat_age  cat_gender      rehabilitation  \
# 122044                 NaN      16.0      청소년          남성  rehabilitation_not
# 142639                 NaN      17.0      청소년          여성  rehabilitation_not
# 154434                 NaN      16.0      청소년          남성  rehabilitation_not
# 157790                 NaN      15.0      청소년          남성  rehabilitation_not
# 186027                 NaN      17.0      청소년          남성  rehabilitation_not
# 213253                 NaN      14.0      청소년          남성  rehabilitation_not
# 267247                 NaN      15.0      청소년          남성  rehabilitation_not
# 270860                 NaN      14.0      청소년          남성  rehabilitation_not
# 377474                 NaN      17.0      청소년          남성  rehabilitation_not
# 400475                 NaN      15.0      청소년          남성  rehabilitation_not
# 429919                 NaN      17.0      청소년          남성  rehabilitation_not
# 465474                 NaN      15.0      청소년          여성  rehabilitation_not
# 505350                 NaN      16.0      청소년          여성  rehabilitation_not
# 520318                 NaN      17.0      청소년          남성  rehabilitation_not
# 520627                 NaN      17.0      청소년          여성  rehabilitation_not
# 555270                 NaN      16.0      청소년          남성  rehabilitation_not
# 591656                 NaN      17.0      청소년          여성  rehabilitation_not
# 605500                 NaN      14.0      청소년          남성  rehabilitation_not
# 649038                 NaN      14.0      청소년          남성  rehabilitation_not
# 674849                 NaN      15.0      청소년          남성  rehabilitation_not
# 744880                 NaN      15.0      청소년          여성  rehabilitation_not
# 787573                 NaN      16.0      청소년          남성  rehabilitation_not
# 1044616                NaN      17.0      청소년          여성  rehabilitation_not
# 1070055                NaN      17.0      청소년          남성  rehabilitation_not
# 1075524                NaN      15.0      청소년          여성  rehabilitation_not
# 1115694                NaN      17.0      청소년          남성  rehabilitation_not
# 1124351                NaN      16.0      청소년          여성  rehabilitation_not
# 1210809                NaN      17.0      청소년          남성  rehabilitation_not
# 1220567                NaN      16.0      청소년          여성  rehabilitation_not
# 1230783                NaN      16.0      청소년          남성  rehabilitation_not
# 1231832                NaN      16.0      청소년          남성      rehabilitation
# 1325718                NaN      16.0      청소년          남성  rehabilitation_not
#
#         loan_cnt loan_amt
# 122044       0.0      0.0
# 142639       0.0      0.0
# 154434       0.0      0.0
# 157790       0.0      0.0
# 186027       0.0      0.0
# 213253       0.0      0.0
# 267247       0.0      0.0
# 270860       0.0      0.0
# 377474       0.0      0.0
# 400475       0.0      0.0
# 429919       0.0      0.0
# 465474       0.0      0.0
# 505350       0.0      0.0
# 520318       0.0      0.0
# 520627       0.0      0.0
# 555270       0.0      0.0
# 591656       0.0      0.0
# 605500       0.0      0.0
# 649038       0.0      0.0
# 674849       0.0      0.0
# 744880       0.0      0.0
# 787573       0.0      0.0
# 1044616      0.0      0.0
# 1070055      0.0      0.0
# 1075524      0.0      0.0
# 1115694      0.0      0.0
# 1124351      0.0      0.0
# 1210809      0.0      0.0
# 1220567      0.0      0.0
# 1230783      0.0      0.0
# 1231832      0.0      0.0
# 1325718      0.0      0.0
#
# [32 rows x 23 columns]

# %%
n = 0
for i in loan_na_na[loan_na_na["cat_age"] == "청소년"]["application_id"]:
    n += len(loan_result[loan_result["application_id"]==i])
print(n)
# Out:
# 0

# %%
loan_notna_na[loan_notna_na["cat_age"] == "청소년"]
# Out:
#          application_id  user_id  birth_year  gender         insert_time  \
# 94620            578586    13353      2005.0     1.0 2022-06-30 21:22:20
# 111609           523209   446404      2006.0     1.0 2022-03-21 04:47:14
# 253265          2004801   488679      2006.0     1.0 2022-06-26 17:07:59
# 354668            29904   258771      2005.0     0.0 2022-06-01 07:11:31
# 426583          1403690   806320      2007.0     1.0 2022-05-28 11:18:30
# 447432          1482913   671192      2007.0     1.0 2022-05-26 12:17:52
# 479147          1898508   446404      2006.0     1.0 2022-04-18 01:16:52
# 544431           788390   229669      2006.0     1.0 2022-05-13 21:09:35
# 638067          1333011   103899      2008.0     0.0 2022-06-28 13:39:40
# 725651           590715   806320      2007.0     1.0 2022-05-28 11:22:27
# 768399           538450   384497      2005.0     1.0 2022-03-23 00:26:51
# 804923          2076073   490061      2005.0     1.0 2022-04-21 09:29:36
# 815749          1388055    33783      2005.0     0.0 2022-06-16 22:23:49
# 882868           783220   595174      2005.0     0.0 2022-05-12 17:26:31
# 1013403           45248   432987      2005.0     1.0 2022-05-07 17:55:21
# 1088701          508753   258771      2005.0     0.0 2022-06-01 07:07:58
# 1097877          418995   520352      2005.0     1.0 2022-04-10 01:29:52
# 1112780          444462   308212      2006.0     1.0 2022-04-16 19:04:28
# 1135456         1781010   308212      2006.0     1.0 2022-04-11 17:13:01
# 1164717          599096   321395      2008.0     1.0 2022-06-15 01:10:02
# 1220100          398122   229669      2006.0     1.0 2022-05-13 20:48:23
# 1245518         1466072   321395      2008.0     1.0 2022-06-17 08:03:02
# 1275895         2142945   425345      2005.0     1.0 2022-06-23 01:32:10
# 1343326         1953877   595174      2005.0     0.0 2022-05-01 15:31:49
# 1379923         1990571   488679      2006.0     1.0 2022-06-26 17:03:29
#
#          credit_score  yearly_income    income_type company_enter_month  \
# 94620             NaN            0.0    OTHERINCOME                 NaT
# 111609            NaN            0.0    OTHERINCOME                 NaT
# 253265            NaN    898000000.0   EARNEDINCOME          2022-06-01
# 354668            NaN      4000000.0    OTHERINCOME                 NaT
# 426583            NaN     40000000.0     FREELANCER          2022-01-01
# 447432            NaN      2000000.0    OTHERINCOME                 NaT
# 479147            NaN     80000000.0  EARNEDINCOME2          2022-03-01
# 544431            NaN            0.0    OTHERINCOME                 NaT
# 638067            NaN            0.0    OTHERINCOME                 NaT
# 725651            NaN     60000000.0     FREELANCER          2022-01-01
# 768399            NaN      3000000.0     FREELANCER          2022-02-01
# 804923            NaN            0.0    OTHERINCOME                 NaT
# 815749            NaN      1000000.0    OTHERINCOME                 NaT
# 882868            NaN            0.0    OTHERINCOME                 NaT
# 1013403           NaN     10000000.0    OTHERINCOME                 NaT
# 1088701           NaN            0.0    OTHERINCOME                 NaT
# 1097877           NaN      1000000.0    OTHERINCOME                 NaT
# 1112780           NaN     60000000.0    OTHERINCOME                 NaT
# 1135456           NaN      5000000.0    OTHERINCOME                 NaT
# 1164717           NaN      1000000.0    OTHERINCOME                 NaT
# 1220100           NaN            0.0    OTHERINCOME                 NaT
# 1245518           NaN      1000000.0    OTHERINCOME                 NaT
# 1275895           NaN      1000000.0    OTHERINCOME                 NaT
# 1343326           NaN            0.0    OTHERINCOME                 NaT
# 1379923           NaN    980000000.0   EARNEDINCOME          2022-06-01
#
#         employment_type  ... personal_rehabilitation_yn  \
# 94620                기타  ...                        0.0
# 111609               기타  ...                        NaN
# 253265              정규직  ...                        1.0
# 354668               기타  ...                        0.0
# 426583               기타  ...                        0.0
# 447432               기타  ...                        1.0
# 479147              계약직  ...                        NaN
# 544431               기타  ...                        0.0
# 638067               기타  ...                        0.0
# 725651               기타  ...                        0.0
# 768399               기타  ...                        NaN
# 804923               기타  ...                        0.0
# 815749               기타  ...                        0.0
# 882868               기타  ...                        0.0
# 1013403              기타  ...                        0.0
# 1088701              기타  ...                        0.0
# 1097877              기타  ...                        NaN
# 1112780              기타  ...                        NaN
# 1135456              기타  ...                        NaN
# 1164717              기타  ...                        0.0
# 1220100              기타  ...                        0.0
# 1245518              기타  ...                        0.0
# 1275895              기타  ...                        0.0
# 1343326              기타  ...                        0.0
# 1379923             정규직  ...                        1.0
#
#          personal_rehabilitation_complete_yn existing_loan_cnt  \
# 94620                                    NaN               1.0
# 111609                                   NaN               1.0
# 253265                                   0.0               1.0
# 354668                                   NaN               1.0
# 426583                                   NaN               1.0
# 447432                                   1.0               1.0
# 479147                                   NaN               1.0
# 544431                                   NaN               1.0
# 638067                                   NaN               1.0
# 725651                                   NaN               1.0
# 768399                                   NaN               1.0
# 804923                                   NaN               1.0
# 815749                                   NaN               1.0
# 882868                                   NaN               1.0
# 1013403                                  NaN               1.0
# 1088701                                  NaN               1.0
# 1097877                                  NaN               1.0
# 1112780                                  NaN               1.0
# 1135456                                  NaN               1.0
# 1164717                                  NaN               1.0
# 1220100                                  NaN               1.0
# 1245518                                  NaN               1.0
# 1275895                                  NaN               1.0
# 1343326                                  NaN               1.0
# 1379923                                  0.0               1.0
#
#          existing_loan_amt  only_age  cat_age  cat_gender  \
# 94620                  NaN      17.0      청소년          남성
# 111609                 NaN      16.0      청소년          남성
# 253265                 NaN      16.0      청소년          남성
# 354668                 NaN      17.0      청소년          여성
# 426583                 NaN      15.0      청소년          남성
# 447432                 NaN      15.0      청소년          남성
# 479147                 NaN      16.0      청소년          남성
# 544431                 NaN      16.0      청소년          남성
# 638067                 NaN      14.0      청소년          여성
# 725651                 NaN      15.0      청소년          남성
# 768399                 NaN      17.0      청소년          남성
# 804923                 NaN      17.0      청소년          남성
# 815749                 NaN      17.0      청소년          여성
# 882868                 NaN      17.0      청소년          여성
# 1013403                NaN      17.0      청소년          남성
# 1088701                NaN      17.0      청소년          여성
# 1097877                NaN      17.0      청소년          남성
# 1112780                NaN      16.0      청소년          남성
# 1135456                NaN      16.0      청소년          남성
# 1164717                NaN      14.0      청소년          남성
# 1220100                NaN      16.0      청소년          남성
# 1245518                NaN      14.0      청소년          남성
# 1275895                NaN      17.0      청소년          남성
# 1343326                NaN      17.0      청소년          여성
# 1379923                NaN      16.0      청소년          남성
#
#                    rehabilitation loan_cnt loan_amt
# 94620          rehabilitation_not      1.0      0.0
# 111609         rehabilitation_not      1.0      0.0
# 253265             rehabilitation      1.0      0.0
# 354668         rehabilitation_not      1.0      0.0
# 426583         rehabilitation_not      1.0      0.0
# 447432   rehabilitation_completed      1.0      0.0
# 479147         rehabilitation_not      1.0      0.0
# 544431         rehabilitation_not      1.0      0.0
# 638067         rehabilitation_not      1.0      0.0
# 725651         rehabilitation_not      1.0      0.0
# 768399         rehabilitation_not      1.0      0.0
# 804923         rehabilitation_not      1.0      0.0
# 815749         rehabilitation_not      1.0      0.0
# 882868         rehabilitation_not      1.0      0.0
# 1013403        rehabilitation_not      1.0      0.0
# 1088701        rehabilitation_not      1.0      0.0
# 1097877        rehabilitation_not      1.0      0.0
# 1112780        rehabilitation_not      1.0      0.0
# 1135456        rehabilitation_not      1.0      0.0
# 1164717        rehabilitation_not      1.0      0.0
# 1220100        rehabilitation_not      1.0      0.0
# 1245518        rehabilitation_not      1.0      0.0
# 1275895        rehabilitation_not      1.0      0.0
# 1343326        rehabilitation_not      1.0      0.0
# 1379923            rehabilitation      1.0      0.0
#
# [25 rows x 23 columns]

# %%
n = 0
for i in loan_notna_na[loan_notna_na["cat_age"] == "청소년"]["application_id"]:
    n += len(loan_result[loan_result["application_id"]==i])
print(n)
# Out:
# 0

# %%
user_spec
# Out:
#          application_id  user_id  birth_year  gender         insert_time  \
# 0               1249046   118218      1985.0     1.0 2022-06-07 06:28:18
# 1                954900   553686      1968.0     1.0 2022-06-07 14:29:03
# 2                137274    59516      1997.0     1.0 2022-06-07 21:40:22
# 3               1570936   167320      1989.0     1.0 2022-06-07 09:40:27
# 4                967833    33400      2000.0     1.0 2022-06-07 08:55:07
# ...                 ...      ...         ...     ...                 ...
# 1394211         1864587   489900      2000.0     1.0 2022-03-22 14:55:32
# 1394212         1327066   151422      1955.0     1.0 2022-03-22 01:19:24
# 1394213         1319606   173524      1983.0     1.0 2022-03-22 07:34:32
# 1394214         1482466   766546      1975.0     1.0 2022-03-22 22:12:35
# 1394215          816537     3864      1977.0     0.0 2022-03-22 08:55:14
#
#          credit_score  yearly_income      income_type company_enter_month  \
# 0               660.0    108000000.0  PRIVATEBUSINESS          2015-11-01
# 1               870.0     30000000.0  PRIVATEBUSINESS          2007-02-01
# 2               710.0     30000000.0       FREELANCER          2021-09-01
# 3               820.0     62000000.0     EARNEDINCOME          2017-01-01
# 4               630.0     36000000.0     EARNEDINCOME          2021-09-01
# ...               ...            ...              ...                 ...
# 1394211         590.0     25000000.0       FREELANCER          2021-06-01
# 1394212         980.0     20000000.0      OTHERINCOME                 NaT
# 1394213         750.0     75000000.0     EARNEDINCOME          2009-08-01
# 1394214         640.0     50000000.0     EARNEDINCOME          2017-05-01
# 1394215           NaN     35000000.0       FREELANCER          2011-03-01
#
#         employment_type  ... personal_rehabilitation_yn  \
# 0                    기타  ...                        0.0
# 1                   정규직  ...                        0.0
# 2                    기타  ...                        0.0
# 3                   정규직  ...                        0.0
# 4                   정규직  ...                        0.0
# ...                 ...  ...                        ...
# 1394211              기타  ...                        NaN
# 1394212              기타  ...                        NaN
# 1394213             정규직  ...                        NaN
# 1394214             정규직  ...                        NaN
# 1394215              기타  ...                        NaN
#
#          personal_rehabilitation_complete_yn existing_loan_cnt  \
# 0                                        NaN               4.0
# 1                                        NaN               1.0
# 2                                        NaN               5.0
# 3                                        NaN               7.0
# 4                                        NaN               1.0
# ...                                      ...               ...
# 1394211                                  NaN               NaN
# 1394212                                  NaN               1.0
# 1394213                                  NaN               8.0
# 1394214                                  NaN              10.0
# 1394215                                  NaN               NaN
#
#          existing_loan_amt  only_age  cat_age  cat_gender      rehabilitation  \
# 0              162000000.0      37.0       중년          남성  rehabilitation_not
# 1               27000000.0      54.0       장년          남성  rehabilitation_not
# 2               15000000.0      25.0       청년          남성  rehabilitation_not
# 3              344000000.0      33.0       중년          남성  rehabilitation_not
# 4               16000000.0      22.0       청년          남성  rehabilitation_not
# ...                    ...       ...      ...         ...                 ...
# 1394211                NaN      22.0       청년          남성  rehabilitation_not
# 1394212                NaN      67.0       노년          남성  rehabilitation_not
# 1394213        200000000.0      39.0       중년          남성  rehabilitation_not
# 1394214        117000000.0      47.0       중년          남성  rehabilitation_not
# 1394215                NaN      45.0       중년          여성  rehabilitation_not
#
#         loan_cnt     loan_amt
# 0            4.0  162000000.0
# 1            1.0   27000000.0
# 2            5.0   15000000.0
# 3            7.0  344000000.0
# 4            1.0   16000000.0
# ...          ...          ...
# 1394211      0.0          0.0
# 1394212      1.0          0.0
# 1394213      8.0  200000000.0
# 1394214     10.0  117000000.0
# 1394215      0.0          0.0
#
# [1394127 rows x 23 columns]

# %%
user_spec["loan_cnt"] = user_spec["existing_loan_cnt"].copy()
user_spec["loan_amt"] = user_spec["existing_loan_amt"].copy()

# %%
user_spec.loc[:,["loan_cnt", "loan_amt"]] = user_spec.loc[:,["loan_cnt", "loan_amt"]].fillna(0)

# %%
user_spec.isna().sum()
# Out:
# application_id                               0
# user_id                                      0
# birth_year                                9723
# gender                                    9723
# insert_time                                  0
# credit_score                            105111
# yearly_income                                0
# income_type                                  0
# company_enter_month                     171672
# employment_type                              0
# houseown_type                                0
# desired_amount                               0
# purpose                                      0
# personal_rehabilitation_yn              587376
# personal_rehabilitation_complete_yn    1381418
# existing_loan_cnt                       198539
# existing_loan_amt                       313751
# only_age                                  9723
# cat_age                                      0
# cat_gender                                   0
# rehabilitation                               0
# loan_cnt                                     0
# loan_amt                                     0
# dtype: int64

# %% [markdown]
# ## 어플 사용자 경우의 수

# %% [markdown]
# 1. 개인정보 null, log 확인시 complete 이후에 end가 없다면 -> 다른 업무를 위해 어플을 사용할 가능성!
#
# 2. 개인정보 null, log 확인시 complete 이후에 end가 있다면 -> 오류일 가능성!
#
# 3. 개인정보 not-null, application_id가 loan_result에 있다면 -> 대출받을 사람임!
#
# 4. 개인정보 not-null, application_id가 loan_result에 없다면 -> 다른 업무를 위해 어플을 사용할 가능성!

# %% [markdown]
# #1,2번
# user_info_nan = user_spec[(user_spec["income_type"].isna()) & (user_spec["employment_type"].isna()) &
#          (user_spec["houseown_type"].isna()) & (user_spec["desired_amount"].isna()) &
#                 (user_spec["purpose"].isna()) & (user_spec["yearly_income"].isna())][["application_id","user_id"]]
#
# true_index=[]
# for i in tqdm_notebook(range(len(tmp))):
#     log_tmp = log_data[log_data["user_id"] == user_info_nan.iloc[i,1]]
#     user_tmp = user_spec[user_spec["application_id"] == user_info_nan.iloc[i,0]]
#
#     true_index.append(log_tmp[(log_tmp["timestamp"].dt.month == user_tmp["insert_time"].dt.month.mean()) &
#     (log_tmp["timestamp"].dt.day == user_tmp["insert_time"].dt.day.mean())]["event"].isin(["EndLoanApply"]).max())

# %% [markdown]
# user_info_nan["complete"] = true_index
# user_info_nan

# %% [markdown]
# #2번에 해당하는 경우
# user_info_nan[user_info_nan["complete"] == True].shape

# %% [markdown]
# #3,4번
# app_tmp = user_spec[(-user_spec["income_type"].isna()) & (-user_spec["employment_type"].isna()) &
#          (-user_spec["houseown_type"].isna()) & (-user_spec["desired_amount"].isna()) &
#                 (-user_spec["purpose"].isna()) & (-user_spec["yearly_income"].isna())]["application_id"]
#
# true_index2=[]
# for i in tqdm_notebook(app_tmp):
#     if len(loan_result[loan_result["application_id"] == i]) == 0:
#         true_index2.append(False)
#     else:
#         true_index2.append(True)

# %% [markdown]
# np.mean(true_index2)
